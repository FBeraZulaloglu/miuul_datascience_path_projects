# %% [markdown]
# # FLO RFM ANALYSIS

# %%
import pandas as pd
import datetime as dt

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
flo_data_ = pd.read_csv("./flo_data_20k.csv")

# %% [markdown]
# # TASK 1

# %% [markdown]
# ## Step 1: Copy the data frame

# %%
flodf = flo_data_.copy()
flodf.head()
# Out:
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 4       2019-08-03      2021-03-07             2021-03-07
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                         4.00
# 1              2020-01-10                        19.00
# 2              2019-12-01                         3.00
# 3              2021-01-06                         1.00
# 4              2019-08-03                         1.00
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                          1.00                             139.99
# 1                          2.00                             159.97
# 2                          2.00                             189.97
# 3                          1.00                              39.99
# 4                          1.00                              49.99
#
#    customer_value_total_ever_online       interested_in_categories_12
# 0                            799.38                           [KADIN]
# 1                           1853.58  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                            395.35                    [ERKEK, KADIN]
# 3                             81.98               [AKTIFCOCUK, COCUK]
# 4                            159.99                       [AKTIFSPOR]

# %% [markdown]
# ## Step 2: Understand the data

# %%
def observe_dataframe_basic(df):
    print("--------------------- First 10 Observation -------------------------")
    print(df.head(10))
    print("--------------------- Features -------------------------------------")
    print(df.columns)
    print("--------------------- Statistics -----------------------------------")
    print(df.describe([0, 0.05, 0.50, 0.95, 0.99, 1]).T)
    print("----------------------- NA -----------------------------------------")
    print(df.isnull().sum())
    print("----------------------- Types,Shape --------------------------------")
    print(df.dtypes) # df.info() can be used too
    print(df.shape)

# %%
observe_dataframe_basic(flodf)
# Out:
# --------------------- First 10 Observation -------------------------
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
# 5  e585280e-aae1-11e9-a2fc-000d3a38a36f       Desktop            Offline
# 6  c445e4ee-6242-11ea-9d1a-000d3a38a36f   Android App        Android App
# 7  3f1b4dc8-8a7d-11ea-8ec0-000d3a38a36f        Mobile            Offline
# 8  cfbda69e-5b4f-11ea-aca7-000d3a38a36f   Android App        Android App
# 9  1143f032-440d-11ea-8b43-000d3a38a36f        Mobile             Mobile
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 4       2019-08-03      2021-03-07             2021-03-07
# 5       2018-11-18      2021-03-13             2018-11-18
# 6       2020-03-04      2020-10-18             2020-10-18
# 7       2020-05-15      2020-08-12             2020-05-15
# 8       2020-01-23      2021-03-07             2021-03-07
# 9       2019-07-30      2020-10-04             2020-10-04
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                         4.00
# 1              2020-01-10                        19.00
# 2              2019-12-01                         3.00
# 3              2021-01-06                         1.00
# 4              2019-08-03                         1.00
# 5              2021-03-13                         1.00
# 6              2020-03-04                         3.00
# 7              2020-08-12                         1.00
# 8              2020-01-25                         3.00
# 9              2019-07-30                         1.00
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                          1.00                             139.99
# 1                          2.00                             159.97
# 2                          2.00                             189.97
# 3                          1.00                              39.99
# 4                          1.00                              49.99
# 5                          2.00                             150.87
# 6                          1.00                              59.99
# 7                          1.00                              49.99
# 8                          2.00                             120.48
# 9                          1.00                              69.98
#
#    customer_value_total_ever_online       interested_in_categories_12
# 0                            799.38                           [KADIN]
# 1                           1853.58  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                            395.35                    [ERKEK, KADIN]
# 3                             81.98               [AKTIFCOCUK, COCUK]
# 4                            159.99                       [AKTIFSPOR]
# 5                             49.99                           [KADIN]
# 6                            315.94                       [AKTIFSPOR]
# 7                            113.64                           [COCUK]
# 8                            934.21             [ERKEK, COCUK, KADIN]
# 9                             95.98                [KADIN, AKTIFSPOR]
# --------------------- Features -------------------------------------
# Index(['master_id', 'order_channel', 'last_order_channel', 'first_order_date',
#        'last_order_date', 'last_order_date_online', 'last_order_date_offline',
#        'order_num_total_ever_online', 'order_num_total_ever_offline',
#        'customer_value_total_ever_offline', 'customer_value_total_ever_online',
#        'interested_in_categories_12'],
#       dtype='object')
# --------------------- Statistics -----------------------------------
#                                      count   mean    std   min    0%    5%  \
# order_num_total_ever_online       19945.00   3.11   4.23  1.00  1.00  1.00
# order_num_total_ever_offline      19945.00   1.91   2.06  1.00  1.00  1.00
# customer_value_total_ever_offline 19945.00 253.92 301.53 10.00 10.00 39.99
# customer_value_total_ever_online  19945.00 497.32 832.60 12.99 12.99 63.99
#
#                                      50%     95%     99%     100%      max
# order_num_total_ever_online         2.00   10.00   20.00   200.00   200.00
# order_num_total_ever_offline        1.00    4.00    7.00   109.00   109.00
# customer_value_total_ever_offline 179.98  694.22 1219.95 18119.14 18119.14
# customer_value_total_ever_online  286.46 1556.73 3143.81 45220.13 45220.13
# ----------------------- NA -----------------------------------------
# master_id                            0
# order_channel                        0
# last_order_channel                   0
# first_order_date                     0
# last_order_date                      0
# last_order_date_online               0
# last_order_date_offline              0
# order_num_total_ever_online          0
# order_num_total_ever_offline         0
# customer_value_total_ever_offline    0
# customer_value_total_ever_online     0
# interested_in_categories_12          0
# dtype: int64
# ----------------------- Types,Shape --------------------------------
# master_id                             object
# order_channel                         object
# last_order_channel                    object
# first_order_date                      object
# last_order_date                       object
# last_order_date_online                object
# last_order_date_offline               object
# order_num_total_ever_online          float64
# order_num_total_ever_offline         float64
# customer_value_total_ever_offline    float64
# customer_value_total_ever_online     float64
# interested_in_categories_12           object
# dtype: object
# (19945, 12)

# %% [markdown]
# ## Step 3: Create Total_Shopping_Count and Total_Shopping_Price

# %% [markdown]
# * For omnichannel customers which is they buy from online and offline platforms we are going to calculate the total amount of the shopping count and the total amount of the money that has spent.

# %%
flodf["master_id"].nunique() # Every customer has an unique id !!
# Out:
# 19945

# %%
flodf["order_num_total_ever_omnichannel"] = flodf["order_num_total_ever_online"] + flodf["order_num_total_ever_offline"]
flodf.head()
# Out:
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 4       2019-08-03      2021-03-07             2021-03-07
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                         4.00
# 1              2020-01-10                        19.00
# 2              2019-12-01                         3.00
# 3              2021-01-06                         1.00
# 4              2019-08-03                         1.00
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                          1.00                             139.99
# 1                          2.00                             159.97
# 2                          2.00                             189.97
# 3                          1.00                              39.99
# 4                          1.00                              49.99
#
#    customer_value_total_ever_online       interested_in_categories_12  \
# 0                            799.38                           [KADIN]
# 1                           1853.58  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                            395.35                    [ERKEK, KADIN]
# 3                             81.98               [AKTIFCOCUK, COCUK]
# 4                            159.99                       [AKTIFSPOR]
#
#    order_num_total_ever_omnichannel
# 0                              5.00
# 1                             21.00
# 2                              5.00
# 3                              2.00
# 4                              2.00

# %%
flodf["customer_value_total_ever_omnichannel"] = flodf["customer_value_total_ever_online"] + flodf["customer_value_total_ever_offline"]
flodf.head()
# Out:
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 4       2019-08-03      2021-03-07             2021-03-07
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                         4.00
# 1              2020-01-10                        19.00
# 2              2019-12-01                         3.00
# 3              2021-01-06                         1.00
# 4              2019-08-03                         1.00
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                          1.00                             139.99
# 1                          2.00                             159.97
# 2                          2.00                             189.97
# 3                          1.00                              39.99
# 4                          1.00                              49.99
#
#    customer_value_total_ever_online       interested_in_categories_12  \
# 0                            799.38                           [KADIN]
# 1                           1853.58  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                            395.35                    [ERKEK, KADIN]
# 3                             81.98               [AKTIFCOCUK, COCUK]
# 4                            159.99                       [AKTIFSPOR]
#
#    order_num_total_ever_omnichannel  customer_value_total_ever_omnichannel
# 0                              5.00                                 939.37
# 1                             21.00                                2013.55
# 2                              5.00                                 585.32
# 3                              2.00                                 121.97
# 4                              2.00                                 209.98

# %% [markdown]
# ## Step 4: Look at the variable types and make type conversion for dates

# %%
date_columns = [column for column in flodf if "date" in column]
#date_colums = df.columns[df.columns.str.contains("date")]
date_columns
# Out:
# ['first_order_date',
#  'last_order_date',
#  'last_order_date_online',
#  'last_order_date_offline']

# %%
# First mehod to do:
for column in date_columns:
    flodf[column] = pd.to_datetime(flodf[column])

# %%
# As a second method:
#flodf[date_columns].apply(pd.to_datetime)

# %%
flodf.dtypes
# Out:
# master_id                                        object
# order_channel                                    object
# last_order_channel                               object
# first_order_date                         datetime64[ns]
# last_order_date                          datetime64[ns]
# last_order_date_online                   datetime64[ns]
# last_order_date_offline                  datetime64[ns]
# order_num_total_ever_online                     float64
# order_num_total_ever_offline                    float64
# customer_value_total_ever_offline               float64
# customer_value_total_ever_online                float64
# interested_in_categories_12                      object
# order_num_total_ever_omnichannel                float64
# customer_value_total_ever_omnichannel           float64
# dtype: object

# %% [markdown]
# ## Step 5: Look at the distrubiton of "number of customers", "total amount of product", "total amount of customer value"

# %%
print(flodf["master_id"].describe([0, 0.05, 0.50, 0.95, 0.99, 1]).T)
# Out:
# count                                    19945
# unique                                   19945
# top       cc294636-19f0-11eb-8d74-000d3a38a36f
# freq                                         1
# Name: master_id, dtype: object

# %%
flodf.groupby("order_channel").agg({"master_id":"count",
                             "order_num_total_ever_omnichannel":"sum",
                             "customer_value_total_ever_omnichannel":"sum"})
# Out:
#                master_id  order_num_total_ever_omnichannel  \
# order_channel
# Android App         9495                          52269.00
# Desktop             2735                          10920.00
# Ios App             2833                          15351.00
# Mobile              4882                          21679.00
#
#                customer_value_total_ever_omnichannel
# order_channel
# Android App                               7819062.76
# Desktop                                   1610321.46
# Ios App                                   2525999.93
# Mobile                                    3028183.16

# %%
flodf.sort_values("customer_value_total_ever_omnichannel",ascending=False).head(10)
# Out:
#                                   master_id order_channel last_order_channel  \
# 11150  5d1c466a-9cfd-11e9-9897-000d3a38a36f   Android App            Desktop
# 4315   d5ef8058-a5c6-11e9-a2fc-000d3a38a36f   Android App        Android App
# 7613   73fd19aa-9e37-11e9-9897-000d3a38a36f       Ios App            Offline
# 13880  7137a5c0-7aad-11ea-8f20-000d3a38a36f       Ios App            Offline
# 9055   47a642fe-975b-11eb-8c2a-000d3a38a36f   Android App            Offline
# 7330   a4d534a2-5b1b-11eb-8dbd-000d3a38a36f       Desktop            Desktop
# 8068   d696c654-2633-11ea-8e1c-000d3a38a36f       Ios App            Ios App
# 163    fef57ffa-aae6-11e9-a2fc-000d3a38a36f        Mobile            Desktop
# 7223   cba59206-9dd1-11e9-9897-000d3a38a36f   Android App        Android App
# 18767  fc0ce7a4-9d87-11e9-9897-000d3a38a36f       Desktop            Desktop
#
#       first_order_date last_order_date last_order_date_online  \
# 11150       2013-10-11      2021-04-30             2021-04-30
# 4315        2018-08-06      2021-02-23             2021-02-23
# 7613        2014-01-14      2021-05-18             2021-01-30
# 13880       2021-03-01      2021-04-13             2021-03-18
# 9055        2021-04-07      2021-04-27             2021-04-07
# 7330        2020-02-16      2021-04-30             2021-04-30
# 8068        2017-05-10      2021-04-13             2021-04-13
# 163         2016-11-08      2021-05-12             2021-05-12
# 7223        2013-02-21      2021-05-09             2021-05-09
# 18767       2018-11-24      2020-11-11             2020-11-11
#
#       last_order_date_offline  order_num_total_ever_online  \
# 11150              2020-12-24                       200.00
# 4315               2020-07-06                        67.00
# 7613               2021-05-18                        81.00
# 13880              2021-04-13                        10.00
# 9055               2021-04-27                         1.00
# 7330               2020-12-18                        66.00
# 8068               2019-08-15                        69.00
# 163                2020-07-09                        36.00
# 7223               2020-01-25                       130.00
# 18767              2019-12-06                        18.00
#
#        order_num_total_ever_offline  customer_value_total_ever_offline  \
# 11150                          2.00                             684.97
# 4315                           1.00                             130.49
# 7613                           1.00                            1263.76
# 13880                          1.00                             538.94
# 9055                           3.00                           18119.14
# 7330                           4.00                             843.68
# 8068                           1.00                              82.48
# 163                            1.00                             180.73
# 7223                           1.00                              49.99
# 18767                          2.00                              64.97
#
#        customer_value_total_ever_online  \
# 11150                          45220.13
# 4315                           36687.80
# 7613                           32654.34
# 13880                          30688.47
# 9055                            2587.20
# 7330                           17599.89
# 8068                           16836.09
# 163                            12545.37
# 7223                           12232.25
# 18767                          12038.18
#
#                         interested_in_categories_12  \
# 11150  [AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]
# 4315          [AKTIFCOCUK, ERKEK, KADIN, AKTIFSPOR]
# 7613               [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 13880                     [ERKEK, KADIN, AKTIFSPOR]
# 9055                                    [AKTIFSPOR]
# 7330                      [ERKEK, KADIN, AKTIFSPOR]
# 8068   [AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]
# 163                              [ERKEK, AKTIFSPOR]
# 7223          [AKTIFCOCUK, ERKEK, KADIN, AKTIFSPOR]
# 18767                                [ERKEK, KADIN]
#
#        order_num_total_ever_omnichannel  customer_value_total_ever_omnichannel
# 11150                            202.00                               45905.10
# 4315                              68.00                               36818.29
# 7613                              82.00                               33918.10
# 13880                             11.00                               31227.41
# 9055                               4.00                               20706.34
# 7330                              70.00                               18443.57
# 8068                              70.00                               16918.57
# 163                               37.00                               12726.10
# 7223                             131.00                               12282.24
# 18767                             20.00                               12103.15

# %%
flodf.sort_values("order_num_total_ever_omnichannel",ascending=False).head(10)
# Out:
#                                   master_id order_channel last_order_channel  \
# 11150  5d1c466a-9cfd-11e9-9897-000d3a38a36f   Android App            Desktop
# 7223   cba59206-9dd1-11e9-9897-000d3a38a36f   Android App        Android App
# 8783   a57f4302-b1a8-11e9-89fa-000d3a38a36f   Android App            Offline
# 2619   fdbe8304-a7ab-11e9-a2fc-000d3a38a36f   Android App            Offline
# 6322   329968c6-a0e2-11e9-a2fc-000d3a38a36f       Ios App            Ios App
# 7613   73fd19aa-9e37-11e9-9897-000d3a38a36f       Ios App            Offline
# 9347   44d032ee-a0d4-11e9-a2fc-000d3a38a36f        Mobile             Mobile
# 10954  b27e241a-a901-11e9-a2fc-000d3a38a36f        Mobile             Mobile
# 8068   d696c654-2633-11ea-8e1c-000d3a38a36f       Ios App            Ios App
# 7330   a4d534a2-5b1b-11eb-8dbd-000d3a38a36f       Desktop            Desktop
#
#       first_order_date last_order_date last_order_date_online  \
# 11150       2013-10-11      2021-04-30             2021-04-30
# 7223        2013-02-21      2021-05-09             2021-05-09
# 8783        2019-08-07      2020-11-04             2020-09-07
# 2619        2018-10-18      2020-06-30             2018-10-18
# 6322        2019-02-14      2021-04-05             2021-04-05
# 7613        2014-01-14      2021-05-18             2021-01-30
# 9347        2019-02-11      2021-02-11             2021-02-11
# 10954       2015-09-12      2021-04-01             2021-04-01
# 8068        2017-05-10      2021-04-13             2021-04-13
# 7330        2020-02-16      2021-04-30             2021-04-30
#
#       last_order_date_offline  order_num_total_ever_online  \
# 11150              2020-12-24                       200.00
# 7223               2020-01-25                       130.00
# 8783               2020-11-04                         2.00
# 2619               2020-06-30                         1.00
# 6322               2020-02-17                         2.00
# 7613               2021-05-18                        81.00
# 9347               2020-12-24                         3.00
# 10954              2019-10-08                        72.00
# 8068               2019-08-15                        69.00
# 7330               2020-12-18                        66.00
#
#        order_num_total_ever_offline  customer_value_total_ever_offline  \
# 11150                          2.00                             684.97
# 7223                           1.00                              49.99
# 8783                         109.00                           10239.46
# 2619                          87.00                            8432.25
# 6322                          81.00                            3997.55
# 7613                           1.00                            1263.76
# 9347                          74.00                            4640.77
# 10954                          3.00                             292.93
# 8068                           1.00                              82.48
# 7330                           4.00                             843.68
#
#        customer_value_total_ever_online  \
# 11150                          45220.13
# 7223                           12232.25
# 8783                             143.98
# 2619                             139.98
# 6322                             242.81
# 7613                           32654.34
# 9347                             543.28
# 10954                           5004.95
# 8068                           16836.09
# 7330                           17599.89
#
#                         interested_in_categories_12  \
# 11150  [AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]
# 7223          [AKTIFCOCUK, ERKEK, KADIN, AKTIFSPOR]
# 8783   [AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2619                                        [ERKEK]
# 6322                                        [ERKEK]
# 7613               [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 9347                             [KADIN, AKTIFSPOR]
# 10954         [AKTIFCOCUK, ERKEK, KADIN, AKTIFSPOR]
# 8068   [AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]
# 7330                      [ERKEK, KADIN, AKTIFSPOR]
#
#        order_num_total_ever_omnichannel  customer_value_total_ever_omnichannel
# 11150                            202.00                               45905.10
# 7223                             131.00                               12282.24
# 8783                             111.00                               10383.44
# 2619                              88.00                                8572.23
# 6322                              83.00                                4240.36
# 7613                              82.00                               33918.10
# 9347                              77.00                                5184.05
# 10954                             75.00                                5297.88
# 8068                              70.00                               16918.57
# 7330                              70.00                               18443.57

# %% [markdown]
# ## Step 6: Functionize the data preprocessing

# %%
def convert_to_datetime(df):
    date_columns = [column for column in df if "date" in column]
    for column in date_columns:
        df[column] = pd.to_datetime(df[column])

# %%
def preprocess(df,sample_size=10):
    observe_dataframe_basic(df)
    df["order_num_total_ever_omnichannel"] = df["order_num_total_ever_online"] + df["order_num_total_ever_offline"]
    df["customer_value_total_ever_omnichannel"] = df["customer_value_total_ever_online"] + df["customer_value_total_ever_offline"]
    convert_to_datetime(df)
    observe_dataframe_basic(df)
    return df

# %%
df = pd.read_csv("./flo_data_20k.csv")
df_flo = preprocess(df)
# Out:
# --------------------- First 10 Observation -------------------------
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
# 5  e585280e-aae1-11e9-a2fc-000d3a38a36f       Desktop            Offline
# 6  c445e4ee-6242-11ea-9d1a-000d3a38a36f   Android App        Android App
# 7  3f1b4dc8-8a7d-11ea-8ec0-000d3a38a36f        Mobile            Offline
# 8  cfbda69e-5b4f-11ea-aca7-000d3a38a36f   Android App        Android App
# 9  1143f032-440d-11ea-8b43-000d3a38a36f        Mobile             Mobile
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 4       2019-08-03      2021-03-07             2021-03-07
# 5       2018-11-18      2021-03-13             2018-11-18
# 6       2020-03-04      2020-10-18             2020-10-18
# 7       2020-05-15      2020-08-12             2020-05-15
# 8       2020-01-23      2021-03-07             2021-03-07
# 9       2019-07-30      2020-10-04             2020-10-04
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                         4.00
# 1              2020-01-10                        19.00
# 2              2019-12-01                         3.00
# 3              2021-01-06                         1.00
# 4              2019-08-03                         1.00
# 5              2021-03-13                         1.00
# 6              2020-03-04                         3.00
# 7              2020-08-12                         1.00
# 8              2020-01-25                         3.00
# 9              2019-07-30                         1.00
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                          1.00                             139.99
# 1                          2.00                             159.97
# 2                          2.00                             189.97
# 3                          1.00                              39.99
# 4                          1.00                              49.99
# 5                          2.00                             150.87
# 6                          1.00                              59.99
# 7                          1.00                              49.99
# 8                          2.00                             120.48
# 9                          1.00                              69.98
#
#    customer_value_total_ever_online       interested_in_categories_12
# 0                            799.38                           [KADIN]
# 1                           1853.58  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                            395.35                    [ERKEK, KADIN]
# 3                             81.98               [AKTIFCOCUK, COCUK]
# 4                            159.99                       [AKTIFSPOR]
# 5                             49.99                           [KADIN]
# 6                            315.94                       [AKTIFSPOR]
# 7                            113.64                           [COCUK]
# 8                            934.21             [ERKEK, COCUK, KADIN]
# 9                             95.98                [KADIN, AKTIFSPOR]
# --------------------- Features -------------------------------------
# Index(['master_id', 'order_channel', 'last_order_channel', 'first_order_date',
#        'last_order_date', 'last_order_date_online', 'last_order_date_offline',
#        'order_num_total_ever_online', 'order_num_total_ever_offline',
#        'customer_value_total_ever_offline', 'customer_value_total_ever_online',
#        'interested_in_categories_12'],
#       dtype='object')
# --------------------- Statistics -----------------------------------
#                                      count   mean    std   min    0%    5%  \
# order_num_total_ever_online       19945.00   3.11   4.23  1.00  1.00  1.00
# order_num_total_ever_offline      19945.00   1.91   2.06  1.00  1.00  1.00
# customer_value_total_ever_offline 19945.00 253.92 301.53 10.00 10.00 39.99
# customer_value_total_ever_online  19945.00 497.32 832.60 12.99 12.99 63.99
#
#                                      50%     95%     99%     100%      max
# order_num_total_ever_online         2.00   10.00   20.00   200.00   200.00
# order_num_total_ever_offline        1.00    4.00    7.00   109.00   109.00
# customer_value_total_ever_offline 179.98  694.22 1219.95 18119.14 18119.14
# customer_value_total_ever_online  286.46 1556.73 3143.81 45220.13 45220.13
# ----------------------- NA -----------------------------------------
# master_id                            0
# order_channel                        0
# last_order_channel                   0
# first_order_date                     0
# last_order_date                      0
# last_order_date_online               0
# last_order_date_offline              0
# order_num_total_ever_online          0
# order_num_total_ever_offline         0
# customer_value_total_ever_offline    0
# customer_value_total_ever_online     0
# interested_in_categories_12          0
# dtype: int64
# ----------------------- Types,Shape --------------------------------
# master_id                             object
# order_channel                         object
# last_order_channel                    object
# first_order_date                      object
# last_order_date                       object
# last_order_date_online                object
# last_order_date_offline               object
# order_num_total_ever_online          float64
# order_num_total_ever_offline         float64
# customer_value_total_ever_offline    float64
# customer_value_total_ever_online     float64
# interested_in_categories_12           object
# dtype: object
# (19945, 12)
# --------------------- First 10 Observation -------------------------
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
# 5  e585280e-aae1-11e9-a2fc-000d3a38a36f       Desktop            Offline
# 6  c445e4ee-6242-11ea-9d1a-000d3a38a36f   Android App        Android App
# 7  3f1b4dc8-8a7d-11ea-8ec0-000d3a38a36f        Mobile            Offline
# 8  cfbda69e-5b4f-11ea-aca7-000d3a38a36f   Android App        Android App
# 9  1143f032-440d-11ea-8b43-000d3a38a36f        Mobile             Mobile
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 4       2019-08-03      2021-03-07             2021-03-07
# 5       2018-11-18      2021-03-13             2018-11-18
# 6       2020-03-04      2020-10-18             2020-10-18
# 7       2020-05-15      2020-08-12             2020-05-15
# 8       2020-01-23      2021-03-07             2021-03-07
# 9       2019-07-30      2020-10-04             2020-10-04
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                         4.00
# 1              2020-01-10                        19.00
# 2              2019-12-01                         3.00
# 3              2021-01-06                         1.00
# 4              2019-08-03                         1.00
# 5              2021-03-13                         1.00
# 6              2020-03-04                         3.00
# 7              2020-08-12                         1.00
# 8              2020-01-25                         3.00
# 9              2019-07-30                         1.00
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                          1.00                             139.99
# 1                          2.00                             159.97
# 2                          2.00                             189.97
# 3                          1.00                              39.99
# 4                          1.00                              49.99
# 5                          2.00                             150.87
# 6                          1.00                              59.99
# 7                          1.00                              49.99
# 8                          2.00                             120.48
# 9                          1.00                              69.98
#
#    customer_value_total_ever_online       interested_in_categories_12  \
# 0                            799.38                           [KADIN]
# 1                           1853.58  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                            395.35                    [ERKEK, KADIN]
# 3                             81.98               [AKTIFCOCUK, COCUK]
# 4                            159.99                       [AKTIFSPOR]
# 5                             49.99                           [KADIN]
# 6                            315.94                       [AKTIFSPOR]
# 7                            113.64                           [COCUK]
# 8                            934.21             [ERKEK, COCUK, KADIN]
# 9                             95.98                [KADIN, AKTIFSPOR]
#
#    order_num_total_ever_omnichannel  customer_value_total_ever_omnichannel
# 0                              5.00                                 939.37
# 1                             21.00                                2013.55
# 2                              5.00                                 585.32
# 3                              2.00                                 121.97
# 4                              2.00                                 209.98
# 5                              3.00                                 200.86
# 6                              4.00                                 375.93
# 7                              2.00                                 163.63
# 8                              5.00                                1054.69
# 9                              2.00                                 165.96
# --------------------- Features -------------------------------------
# Index(['master_id', 'order_channel', 'last_order_channel', 'first_order_date',
#        'last_order_date', 'last_order_date_online', 'last_order_date_offline',
#        'order_num_total_ever_online', 'order_num_total_ever_offline',
#        'customer_value_total_ever_offline', 'customer_value_total_ever_online',
#        'interested_in_categories_12', 'order_num_total_ever_omnichannel',
#        'customer_value_total_ever_omnichannel'],
#       dtype='object')
# --------------------- Statistics -----------------------------------
#                                          count   mean    std   min    0%  \
# order_num_total_ever_online           19945.00   3.11   4.23  1.00  1.00
# order_num_total_ever_offline          19945.00   1.91   2.06  1.00  1.00
# customer_value_total_ever_offline     19945.00 253.92 301.53 10.00 10.00
# customer_value_total_ever_online      19945.00 497.32 832.60 12.99 12.99
# order_num_total_ever_omnichannel      19945.00   5.02   4.74  2.00  2.00
# customer_value_total_ever_omnichannel 19945.00 751.24 895.40 44.98 44.98
#
#                                           5%    50%     95%     99%     100%  \
# order_num_total_ever_online             1.00   2.00   10.00   20.00   200.00
# order_num_total_ever_offline            1.00   1.00    4.00    7.00   109.00
# customer_value_total_ever_offline      39.99 179.98  694.22 1219.95 18119.14
# customer_value_total_ever_online       63.99 286.46 1556.73 3143.81 45220.13
# order_num_total_ever_omnichannel        2.00   4.00   12.00   22.00   202.00
# customer_value_total_ever_omnichannel 175.48 545.27 1921.92 3606.36 45905.10
#
#                                            max
# order_num_total_ever_online             200.00
# order_num_total_ever_offline            109.00
# customer_value_total_ever_offline     18119.14
# customer_value_total_ever_online      45220.13
# order_num_total_ever_omnichannel        202.00
# customer_value_total_ever_omnichannel 45905.10
# ----------------------- NA -----------------------------------------
# master_id                                0
# order_channel                            0
# last_order_channel                       0
# first_order_date                         0
# last_order_date                          0
# last_order_date_online                   0
# last_order_date_offline                  0
# order_num_total_ever_online              0
# order_num_total_ever_offline             0
# customer_value_total_ever_offline        0
# customer_value_total_ever_online         0
# interested_in_categories_12              0
# order_num_total_ever_omnichannel         0
# customer_value_total_ever_omnichannel    0
# dtype: int64
# ----------------------- Types,Shape --------------------------------
# master_id                                        object
# order_channel                                    object
# last_order_channel                               object
# first_order_date                         datetime64[ns]
# last_order_date                          datetime64[ns]
# last_order_date_online                   datetime64[ns]
# last_order_date_offline                  datetime64[ns]
# order_num_total_ever_online                     float64
# order_num_total_ever_offline                    float64
# customer_value_total_ever_offline               float64
# customer_value_total_ever_online                float64
# interested_in_categories_12                      object
# order_num_total_ever_omnichannel                float64
# customer_value_total_ever_omnichannel           float64
# dtype: object
# (19945, 14)

# %% [markdown]
# # TASK 2

# %% [markdown]
# ## Step 1: What is recency, frequency and monetary for this problem?

# %% [markdown]
# 1. Recency: last_order_date - first_order_date
# 2. Frequency: order_number_ever_total_omnichannel
# 3. Monetary: customer_value_total_ever_omnichannel

# %% [markdown]
# ## Step 2: Calculate rfm (recency,frequency and monetary metrics)

# %%
flodf.columns
# Out:
# Index(['master_id', 'order_channel', 'last_order_channel', 'first_order_date',
#        'last_order_date', 'last_order_date_online', 'last_order_date_offline',
#        'order_num_total_ever_online', 'order_num_total_ever_offline',
#        'customer_value_total_ever_offline', 'customer_value_total_ever_online',
#        'interested_in_categories_12', 'order_num_total_ever_omnichannel',
#        'customer_value_total_ever_omnichannel'],
#       dtype='object')

# %%
flodf.head()
# Out:
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 4       2019-08-03      2021-03-07             2021-03-07
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                         4.00
# 1              2020-01-10                        19.00
# 2              2019-12-01                         3.00
# 3              2021-01-06                         1.00
# 4              2019-08-03                         1.00
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                          1.00                             139.99
# 1                          2.00                             159.97
# 2                          2.00                             189.97
# 3                          1.00                              39.99
# 4                          1.00                              49.99
#
#    customer_value_total_ever_online       interested_in_categories_12  \
# 0                            799.38                           [KADIN]
# 1                           1853.58  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                            395.35                    [ERKEK, KADIN]
# 3                             81.98               [AKTIFCOCUK, COCUK]
# 4                            159.99                       [AKTIFSPOR]
#
#    order_num_total_ever_omnichannel  customer_value_total_ever_omnichannel
# 0                              5.00                                 939.37
# 1                             21.00                                2013.55
# 2                              5.00                                 585.32
# 3                              2.00                                 121.97
# 4                              2.00                                 209.98

# %%
last_date = max(flodf["last_order_date"])
last_date
# Out:
# Timestamp('2021-05-30 00:00:00')

# %% [markdown]
# Today date will be calculated as 2 days after the last date.

# %%
analysis_date = dt.datetime(2021, 6, 1)
analysis_date
# Out:
# datetime.datetime(2021, 6, 1, 0, 0)

# %%
rfm = flodf.groupby('master_id').agg({'last_order_date': lambda last_order_date: (analysis_date - last_order_date),
                                     'order_num_total_ever_omnichannel': lambda order_num_total_ever_omnichannel: order_num_total_ever_omnichannel,
                                     'customer_value_total_ever_omnichannel': lambda customer_value_total_ever_omnichannel: customer_value_total_ever_omnichannel})

# %%
rfm.tail()
# Out:
#                                      last_order_date  \
# master_id
# fff1db94-afd9-11ea-b736-000d3a38a36f        183 days
# fff4736a-60a4-11ea-8dd8-000d3a38a36f         67 days
# fffacd34-ae14-11e9-a2fc-000d3a38a36f        257 days
# fffacecc-ddc3-11e9-a848-000d3a38a36f        132 days
# fffe4b30-18e0-11ea-9213-000d3a38a36f        321 days
#
#                                       order_num_total_ever_omnichannel  \
# master_id
# fff1db94-afd9-11ea-b736-000d3a38a36f                              5.00
# fff4736a-60a4-11ea-8dd8-000d3a38a36f                              2.00
# fffacd34-ae14-11e9-a2fc-000d3a38a36f                              6.00
# fffacecc-ddc3-11e9-a848-000d3a38a36f                              9.00
# fffe4b30-18e0-11ea-9213-000d3a38a36f                              4.00
#
#                                       customer_value_total_ever_omnichannel
# master_id
# fff1db94-afd9-11ea-b736-000d3a38a36f                                 796.87
# fff4736a-60a4-11ea-8dd8-000d3a38a36f                                 318.87
# fffacd34-ae14-11e9-a2fc-000d3a38a36f                                 983.92
# fffacecc-ddc3-11e9-a848-000d3a38a36f                                1362.20
# fffe4b30-18e0-11ea-9213-000d3a38a36f                                 524.69

# %%
rfm.columns = ['recency', 'frequency', 'monetary']
rfm.head()
# Out:
#                                       recency  frequency  monetary
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f  10 days       5.00    776.07
# 00034aaa-a838-11e9-a2fc-000d3a38a36f 298 days       3.00    269.47
# 000be838-85df-11ea-a90b-000d3a38a36f 213 days       4.00    722.69
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f  27 days       7.00    874.16
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f  20 days       7.00   1620.33

# %%
rfm.describe().T
# Out:
#              count                         mean                          std  \
# recency      19945  134 days 11:00:02.346452746  103 days 06:44:51.245382632
# frequency 19945.00                         5.02                         4.74
# monetary  19945.00                       751.24                       895.40
#
#                        min               25%                50%  \
# recency    2 days 00:00:00  43 days 00:00:00  111 days 00:00:00
# frequency             2.00              3.00               4.00
# monetary             44.98            339.98             545.27
#
#                          75%                max
# recency    202 days 00:00:00  367 days 00:00:00
# frequency               6.00             202.00
# monetary              897.78           45905.10

# %% [markdown]
# # TASK 3

# %% [markdown]
# ## Step 1: Calculate RFM score

# %%
rfm["recency_score"] = pd.qcut(rfm['recency'], 5, labels=[5, 4, 3, 2, 1])
rfm["frequency_score"] = pd.qcut(rfm['frequency'].rank(method="first"), 5, labels=[1, 2, 3, 4, 5])
rfm["monetary_score"] = pd.qcut(rfm['monetary'], 5, labels=[1, 2, 3, 4, 5])

# %%
rfm
# Out:
#                                       recency  frequency  monetary  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f  10 days       5.00    776.07
# 00034aaa-a838-11e9-a2fc-000d3a38a36f 298 days       3.00    269.47
# 000be838-85df-11ea-a90b-000d3a38a36f 213 days       4.00    722.69
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f  27 days       7.00    874.16
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f  20 days       7.00   1620.33
# ...                                       ...        ...       ...
# fff1db94-afd9-11ea-b736-000d3a38a36f 183 days       5.00    796.87
# fff4736a-60a4-11ea-8dd8-000d3a38a36f  67 days       2.00    318.87
# fffacd34-ae14-11e9-a2fc-000d3a38a36f 257 days       6.00    983.92
# fffacecc-ddc3-11e9-a848-000d3a38a36f 132 days       9.00   1362.20
# fffe4b30-18e0-11ea-9213-000d3a38a36f 321 days       4.00    524.69
#
#                                      recency_score frequency_score  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f             5               4
# 00034aaa-a838-11e9-a2fc-000d3a38a36f             1               2
# 000be838-85df-11ea-a90b-000d3a38a36f             2               3
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f             5               4
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f             5               4
# ...                                            ...             ...
# fff1db94-afd9-11ea-b736-000d3a38a36f             2               4
# fff4736a-60a4-11ea-8dd8-000d3a38a36f             4               2
# fffacd34-ae14-11e9-a2fc-000d3a38a36f             1               4
# fffacecc-ddc3-11e9-a848-000d3a38a36f             3               5
# fffe4b30-18e0-11ea-9213-000d3a38a36f             1               4
#
#                                      monetary_score
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f              4
# 00034aaa-a838-11e9-a2fc-000d3a38a36f              1
# 000be838-85df-11ea-a90b-000d3a38a36f              4
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f              4
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f              5
# ...                                             ...
# fff1db94-afd9-11ea-b736-000d3a38a36f              4
# fff4736a-60a4-11ea-8dd8-000d3a38a36f              2
# fffacd34-ae14-11e9-a2fc-000d3a38a36f              4
# fffacecc-ddc3-11e9-a848-000d3a38a36f              5
# fffe4b30-18e0-11ea-9213-000d3a38a36f              3
#
# [19945 rows x 6 columns]

# %%
rfm["RF_SCORE"] = (rfm['recency_score'].astype(str) +
                    rfm['frequency_score'].astype(str))

# %%
rfm.head(10)
# Out:
#                                       recency  frequency  monetary  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f  10 days       5.00    776.07
# 00034aaa-a838-11e9-a2fc-000d3a38a36f 298 days       3.00    269.47
# 000be838-85df-11ea-a90b-000d3a38a36f 213 days       4.00    722.69
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f  27 days       7.00    874.16
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f  20 days       7.00   1620.33
# 00136ce2-a562-11e9-a2fc-000d3a38a36f 203 days       2.00    359.45
# 00142f9a-7af6-11eb-8460-000d3a38a36f  25 days       3.00    404.94
# 0014778a-5b11-11ea-9a2c-000d3a38a36f  26 days       3.00    727.43
# 0018c6aa-ab6c-11e9-a2fc-000d3a38a36f 126 days       2.00    317.91
# 0022f41e-5597-11eb-9e65-000d3a38a36f  12 days       2.00    154.98
#
#                                      recency_score frequency_score  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f             5               4
# 00034aaa-a838-11e9-a2fc-000d3a38a36f             1               2
# 000be838-85df-11ea-a90b-000d3a38a36f             2               3
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f             5               4
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f             5               4
# 00136ce2-a562-11e9-a2fc-000d3a38a36f             2               1
# 00142f9a-7af6-11eb-8460-000d3a38a36f             5               2
# 0014778a-5b11-11ea-9a2c-000d3a38a36f             5               2
# 0018c6aa-ab6c-11e9-a2fc-000d3a38a36f             3               1
# 0022f41e-5597-11eb-9e65-000d3a38a36f             5               1
#
#                                      monetary_score RF_SCORE
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f              4       54
# 00034aaa-a838-11e9-a2fc-000d3a38a36f              1       12
# 000be838-85df-11ea-a90b-000d3a38a36f              4       23
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f              4       54
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f              5       54
# 00136ce2-a562-11e9-a2fc-000d3a38a36f              2       21
# 00142f9a-7af6-11eb-8460-000d3a38a36f              2       52
# 0014778a-5b11-11ea-9a2c-000d3a38a36f              4       52
# 0018c6aa-ab6c-11e9-a2fc-000d3a38a36f              2       31
# 0022f41e-5597-11eb-9e65-000d3a38a36f              1       51

# %% [markdown]
# # TASK 4

# %% [markdown]
# ## Step 1:  Make Segmenation On RF Score

# %%
seg_map = {
    r'[1-2][1-2]': 'hibernating',
    r'[1-2][3-4]': 'at_Risk',
    r'[1-2]5': 'cant_loose',
    r'3[1-2]': 'about_to_sleep',
    r'33': 'need_attention',
    r'[3-4][4-5]': 'loyal_customers',
    r'41': 'promising',
    r'51': 'new_customers',
    r'[4-5][2-3]': 'potential_loyalists',
    r'5[4-5]': 'champions'
}

# %%
rfm['segment'] = rfm['RF_SCORE'].replace(seg_map, regex=True)

# %%
rfm.reset_index(inplace=True)

# %% [markdown]
# # TASK 5 Action Timeee :)

# %% [markdown]
# ## Step 1: Get the mean of  recency,frequency,monetary values for each segment

# %%
rfm[["segment", "master_id"]].groupby("segment").agg(["count"])
# Out:
#                     master_id
#                         count
# segment
# about_to_sleep           1643
# at_Risk                  3152
# cant_loose               1194
# champions                1920
# hibernating              3589
# loyal_customers          3375
# need_attention            806
# new_customers             673
# potential_loyalists      2925
# promising                 668

# %%
rfm[["segment", "recency", "frequency", "monetary"]].groupby("segment").agg(["mean"])
# Out:
#                                         recency frequency monetary
#                                            mean      mean     mean
# segment
# about_to_sleep      114 days 00:45:34.510042604      2.41   361.65
# at_Risk             242 days 07:53:45.380710660      4.47   648.33
# cant_loose          235 days 03:49:08.743718592     10.72  1481.65
# champions                      17 days 03:24:45      8.97  1410.71
# hibernating         247 days 10:13:52.543884092      2.39   362.58
# loyal_customers         82 days 13:23:24.800000      8.36  1216.26
# need_attention      113 days 00:53:35.880893300      3.74   553.44
# new_customers        17 days 23:25:45.913818722      2.00   344.05
# potential_loyalists  36 days 20:52:25.846153846      3.31   533.74
# promising            58 days 16:40:14.371257485      2.00   334.15

# %% [markdown]
# ## Step 2: There are 2 cases for a spesific profile. Look for the profiles and be sure to save the customer id's that is suitable for a spesific profile to a csv file with the help of RFM.

# %% [markdown]
# ### A) There is a brand new woman shoes that comes to FLO. This brand's products is generally higher than the mean of the general customers expectations. Because of that, FLO wants to be specilized to make commercials for this new brand to the customers that may be intersted in getting this brand's shoes. FLO is looking for the customers in "champions" and "loyal customers" section also has bought anything from Woman(Kadın) category to contact spesifically. Make sure to save a CSV file which includes all the customers that FLO want spesifically.

# %%
flodf.head()
# Out:
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 4       2019-08-03      2021-03-07             2021-03-07
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                         4.00
# 1              2020-01-10                        19.00
# 2              2019-12-01                         3.00
# 3              2021-01-06                         1.00
# 4              2019-08-03                         1.00
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                          1.00                             139.99
# 1                          2.00                             159.97
# 2                          2.00                             189.97
# 3                          1.00                              39.99
# 4                          1.00                              49.99
#
#    customer_value_total_ever_online       interested_in_categories_12  \
# 0                            799.38                           [KADIN]
# 1                           1853.58  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                            395.35                    [ERKEK, KADIN]
# 3                             81.98               [AKTIFCOCUK, COCUK]
# 4                            159.99                       [AKTIFSPOR]
#
#    order_num_total_ever_omnichannel  customer_value_total_ever_omnichannel
# 0                              5.00                                 939.37
# 1                             21.00                                2013.55
# 2                              5.00                                 585.32
# 3                              2.00                                 121.97
# 4                              2.00                                 209.98

# %%
flodf["interested_in_categories_12"]
# Out:
# 0                                 [KADIN]
# 1        [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                          [ERKEK, KADIN]
# 3                     [AKTIFCOCUK, COCUK]
# 4                             [AKTIFSPOR]
#                        ...
# 19940                  [ERKEK, AKTIFSPOR]
# 19941                         [AKTIFSPOR]
# 19942                         [AKTIFSPOR]
# 19943                  [ERKEK, AKTIFSPOR]
# 19944                  [KADIN, AKTIFSPOR]
# Name: interested_in_categories_12, Length: 19945, dtype: object

# %%
customers_in_woman_sector = [row for index,row in flodf.iterrows() if "KADIN" in row["interested_in_categories_12"]]

# %%
customer_woman_sector_df = pd.DataFrame(customers_in_woman_sector)
customer_woman_sector_df["interested_in_categories_12"].tail()
# Out:
# 19926           [KADIN, AKTIFSPOR]
# 19932    [ERKEK, KADIN, AKTIFSPOR]
# 19934               [ERKEK, KADIN]
# 19937               [COCUK, KADIN]
# 19944           [KADIN, AKTIFSPOR]
# Name: interested_in_categories_12, dtype: object

# %%
rfm.head()
# Out:
#                               master_id  recency  frequency  monetary  \
# 0  00016786-2f5a-11ea-bb80-000d3a38a36f  10 days       5.00    776.07
# 1  00034aaa-a838-11e9-a2fc-000d3a38a36f 298 days       3.00    269.47
# 2  000be838-85df-11ea-a90b-000d3a38a36f 213 days       4.00    722.69
# 3  000c1fe2-a8b7-11ea-8479-000d3a38a36f  27 days       7.00    874.16
# 4  000f5e3e-9dde-11ea-80cd-000d3a38a36f  20 days       7.00   1620.33
#
#   recency_score frequency_score monetary_score RF_SCORE      segment
# 0             5               4              4       54    champions
# 1             1               2              1       12  hibernating
# 2             2               3              4       23      at_Risk
# 3             5               4              4       54    champions
# 4             5               4              5       54    champions

# %%
rfm.set_index(rfm["master_id"],inplace=True)
rfm.drop(['master_id'],axis=1,inplace=True)

# %%
customer_woman_sector_df.set_index(customer_woman_sector_df["master_id"],inplace=True)
customer_woman_sector_df.drop(['master_id'],axis=1,inplace=True)

# %%
customers_speciliazed = pd.merge(rfm, customer_woman_sector_df, left_index=True, right_index=True)
customers_speciliazed["interested_in_categories_12"].value_counts()
# Out:
# [KADIN]                                         2158
# [KADIN, AKTIFSPOR]                              1352
# [ERKEK, KADIN]                                   848
# [ERKEK, KADIN, AKTIFSPOR]                        775
# [COCUK, KADIN]                                   443
# [COCUK, KADIN, AKTIFSPOR]                        241
# [AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]     223
# [ERKEK, COCUK, KADIN, AKTIFSPOR]                 213
# [AKTIFCOCUK, COCUK, KADIN]                       213
# [AKTIFCOCUK, KADIN]                              210
# [ERKEK, COCUK, KADIN]                            204
# [AKTIFCOCUK, COCUK, KADIN, AKTIFSPOR]            203
# [AKTIFCOCUK, KADIN, AKTIFSPOR]                   184
# [AKTIFCOCUK, ERKEK, KADIN, AKTIFSPOR]            132
# [AKTIFCOCUK, ERKEK, COCUK, KADIN]                115
# [AKTIFCOCUK, ERKEK, KADIN]                        89
# Name: interested_in_categories_12, dtype: int64

# %%
result_df = pd.DataFrame()
result_df = customers_speciliazed[(customers_speciliazed["segment"] == "champions") | (customers_speciliazed["segment"] == "loyal_customers")]

# %%
result_df["segment"].value_counts()
# Out:
# loyal_customers    1591
# champions           896
# Name: segment, dtype: int64

# %%
result_df["interested_in_categories_12"].value_counts()
# Out:
# [KADIN, AKTIFSPOR]                              411
# [ERKEK, KADIN, AKTIFSPOR]                       353
# [KADIN]                                         331
# [ERKEK, KADIN]                                  209
# [AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]    169
# [AKTIFCOCUK, COCUK, KADIN, AKTIFSPOR]           130
# [ERKEK, COCUK, KADIN, AKTIFSPOR]                129
# [COCUK, KADIN, AKTIFSPOR]                       120
# [COCUK, KADIN]                                  119
# [AKTIFCOCUK, COCUK, KADIN]                       96
# [AKTIFCOCUK, ERKEK, KADIN, AKTIFSPOR]            83
# [AKTIFCOCUK, KADIN]                              82
# [ERKEK, COCUK, KADIN]                            82
# [AKTIFCOCUK, KADIN, AKTIFSPOR]                   80
# [AKTIFCOCUK, ERKEK, COCUK, KADIN]                60
# [AKTIFCOCUK, ERKEK, KADIN]                       33
# Name: interested_in_categories_12, dtype: int64

# %%
# Without merging:
#rfm[rfm["master_id"].isin(customer_women_sector["master_id"]) & rfm["segment"].isin(["champions","loyal_customers"])]["master_id"]

# %%
new_df = pd.DataFrame()
new_df["special_customer_id_for_new_brand"] = result_df.index
new_df.to_csv("special_brand_customers.csv",index=False)

# %% [markdown]
# ### B) For man and children (ERKEK and COCUK) productions there is gonna be %40 percentage of sale. This sale focus on the customers who has interest in the categories that has mentioned and the customers was active back then and the customers should not be lost by FLO. The main target population is sleepy and new customers. FLO wants to get these customers id in a csv file

# %%
flodf.head()
# Out:
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 4       2019-08-03      2021-03-07             2021-03-07
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                         4.00
# 1              2020-01-10                        19.00
# 2              2019-12-01                         3.00
# 3              2021-01-06                         1.00
# 4              2019-08-03                         1.00
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                          1.00                             139.99
# 1                          2.00                             159.97
# 2                          2.00                             189.97
# 3                          1.00                              39.99
# 4                          1.00                              49.99
#
#    customer_value_total_ever_online       interested_in_categories_12  \
# 0                            799.38                           [KADIN]
# 1                           1853.58  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                            395.35                    [ERKEK, KADIN]
# 3                             81.98               [AKTIFCOCUK, COCUK]
# 4                            159.99                       [AKTIFSPOR]
#
#    order_num_total_ever_omnichannel  customer_value_total_ever_omnichannel
# 0                              5.00                                 939.37
# 1                             21.00                                2013.55
# 2                              5.00                                 585.32
# 3                              2.00                                 121.97
# 4                              2.00                                 209.98

# %%
customers_manChild_sector_df = [row for index,row in flodf.iterrows() if ("ERKEK" in row["interested_in_categories_12"]) or ("COCUK" in row["interested_in_categories_12"]) ]

# %%
customers_manChild_sector_df = pd.DataFrame(customers_manChild_sector_df)
customers_manChild_sector_df.head()
# Out:
#                               master_id order_channel last_order_channel  \
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 7  3f1b4dc8-8a7d-11ea-8ec0-000d3a38a36f        Mobile            Offline
# 8  cfbda69e-5b4f-11ea-aca7-000d3a38a36f   Android App        Android App
#
#   first_order_date last_order_date last_order_date_online  \
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 7       2020-05-15      2020-08-12             2020-05-15
# 8       2020-01-23      2021-03-07             2021-03-07
#
#   last_order_date_offline  order_num_total_ever_online  \
# 1              2020-01-10                        19.00
# 2              2019-12-01                         3.00
# 3              2021-01-06                         1.00
# 7              2020-08-12                         1.00
# 8              2020-01-25                         3.00
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 1                          2.00                             159.97
# 2                          2.00                             189.97
# 3                          1.00                              39.99
# 7                          1.00                              49.99
# 8                          2.00                             120.48
#
#    customer_value_total_ever_online       interested_in_categories_12  \
# 1                           1853.58  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                            395.35                    [ERKEK, KADIN]
# 3                             81.98               [AKTIFCOCUK, COCUK]
# 7                            113.64                           [COCUK]
# 8                            934.21             [ERKEK, COCUK, KADIN]
#
#    order_num_total_ever_omnichannel  customer_value_total_ever_omnichannel
# 1                             21.00                                2013.55
# 2                              5.00                                 585.32
# 3                              2.00                                 121.97
# 7                              2.00                                 163.63
# 8                              5.00                                1054.69

# %%
customers_manChild_sector_df["interested_in_categories_12"].value_counts()
# Out:
# [ERKEK]                                         1973
# [ERKEK, AKTIFSPOR]                              1178
# [ERKEK, KADIN]                                   848
# [COCUK]                                          836
# [ERKEK, KADIN, AKTIFSPOR]                        775
# [AKTIFCOCUK]                                     679
# [COCUK, KADIN]                                   443
# [AKTIFCOCUK, COCUK]                              349
# [COCUK, AKTIFSPOR]                               317
# [AKTIFCOCUK, AKTIFSPOR]                          317
# [COCUK, KADIN, AKTIFSPOR]                        241
# [AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]     223
# [ERKEK, COCUK]                                   215
# [AKTIFCOCUK, COCUK, KADIN]                       213
# [ERKEK, COCUK, KADIN, AKTIFSPOR]                 213
# [AKTIFCOCUK, KADIN]                              210
# [ERKEK, COCUK, KADIN]                            204
# [AKTIFCOCUK, COCUK, KADIN, AKTIFSPOR]            203
# [AKTIFCOCUK, COCUK, AKTIFSPOR]                   202
# [AKTIFCOCUK, KADIN, AKTIFSPOR]                   184
# [ERKEK, COCUK, AKTIFSPOR]                        156
# [AKTIFCOCUK, ERKEK]                              152
# [AKTIFCOCUK, ERKEK, AKTIFSPOR]                   142
# [AKTIFCOCUK, ERKEK, KADIN, AKTIFSPOR]            132
# [AKTIFCOCUK, ERKEK, COCUK]                       122
# [AKTIFCOCUK, ERKEK, COCUK, KADIN]                115
# [AKTIFCOCUK, ERKEK, COCUK, AKTIFSPOR]            105
# [AKTIFCOCUK, ERKEK, KADIN]                        89
# Name: interested_in_categories_12, dtype: int64

# %%
customers_manChild_sector_df.set_index(customers_manChild_sector_df["master_id"],inplace=True)
customers_manChild_sector_df.drop(['master_id'],axis=1,inplace=True)

# %%
flodf.set_index(flodf["master_id"],inplace=True)
flodf.drop(['master_id'],axis=1,inplace=True)

# %%
customers_for_sales = pd.merge(rfm, customers_manChild_sector_df, left_index=True, right_index=True)
customers_for_sales["interested_in_categories_12"].value_counts()
# Out:
# [ERKEK]                                         1973
# [ERKEK, AKTIFSPOR]                              1178
# [ERKEK, KADIN]                                   848
# [COCUK]                                          836
# [ERKEK, KADIN, AKTIFSPOR]                        775
# [AKTIFCOCUK]                                     679
# [COCUK, KADIN]                                   443
# [AKTIFCOCUK, COCUK]                              349
# [AKTIFCOCUK, AKTIFSPOR]                          317
# [COCUK, AKTIFSPOR]                               317
# [COCUK, KADIN, AKTIFSPOR]                        241
# [AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]     223
# [ERKEK, COCUK]                                   215
# [AKTIFCOCUK, COCUK, KADIN]                       213
# [ERKEK, COCUK, KADIN, AKTIFSPOR]                 213
# [AKTIFCOCUK, KADIN]                              210
# [ERKEK, COCUK, KADIN]                            204
# [AKTIFCOCUK, COCUK, KADIN, AKTIFSPOR]            203
# [AKTIFCOCUK, COCUK, AKTIFSPOR]                   202
# [AKTIFCOCUK, KADIN, AKTIFSPOR]                   184
# [ERKEK, COCUK, AKTIFSPOR]                        156
# [AKTIFCOCUK, ERKEK]                              152
# [AKTIFCOCUK, ERKEK, AKTIFSPOR]                   142
# [AKTIFCOCUK, ERKEK, KADIN, AKTIFSPOR]            132
# [AKTIFCOCUK, ERKEK, COCUK]                       122
# [AKTIFCOCUK, ERKEK, COCUK, KADIN]                115
# [AKTIFCOCUK, ERKEK, COCUK, AKTIFSPOR]            105
# [AKTIFCOCUK, ERKEK, KADIN]                        89
# Name: interested_in_categories_12, dtype: int64

# %%
customers_for_sales.head()
# Out:
#                                       recency  frequency  monetary  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f  10 days       5.00    776.07
# 00034aaa-a838-11e9-a2fc-000d3a38a36f 298 days       3.00    269.47
# 000be838-85df-11ea-a90b-000d3a38a36f 213 days       4.00    722.69
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f  27 days       7.00    874.16
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f  20 days       7.00   1620.33
#
#                                      recency_score frequency_score  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f             5               4
# 00034aaa-a838-11e9-a2fc-000d3a38a36f             1               2
# 000be838-85df-11ea-a90b-000d3a38a36f             2               3
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f             5               4
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f             5               4
#
#                                      monetary_score RF_SCORE      segment  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f              4       54    champions
# 00034aaa-a838-11e9-a2fc-000d3a38a36f              1       12  hibernating
# 000be838-85df-11ea-a90b-000d3a38a36f              4       23      at_Risk
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f              4       54    champions
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f              5       54    champions
#
#                                      order_channel last_order_channel  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f        Mobile             Mobile
# 00034aaa-a838-11e9-a2fc-000d3a38a36f       Desktop            Offline
# 000be838-85df-11ea-a90b-000d3a38a36f   Android App            Offline
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f   Android App        Android App
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f   Android App        Android App
#
#                                      first_order_date last_order_date  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f       2019-11-19      2021-05-22
# 00034aaa-a838-11e9-a2fc-000d3a38a36f       2015-11-09      2020-08-07
# 000be838-85df-11ea-a90b-000d3a38a36f       2020-04-16      2020-10-31
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f       2020-06-07      2021-05-05
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f       2020-07-13      2021-05-12
#
#                                      last_order_date_online  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f             2021-05-22
# 00034aaa-a838-11e9-a2fc-000d3a38a36f             2015-11-09
# 000be838-85df-11ea-a90b-000d3a38a36f             2020-04-23
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f             2021-05-05
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f             2021-05-12
#
#                                      last_order_date_offline  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f              2020-10-05
# 00034aaa-a838-11e9-a2fc-000d3a38a36f              2020-08-07
# 000be838-85df-11ea-a90b-000d3a38a36f              2020-10-31
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f              2021-01-29
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f              2021-03-13
#
#                                       order_num_total_ever_online  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f                         2.00
# 00034aaa-a838-11e9-a2fc-000d3a38a36f                         1.00
# 000be838-85df-11ea-a90b-000d3a38a36f                         3.00
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f                         3.00
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f                         5.00
#
#                                       order_num_total_ever_offline  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f                          3.00
# 00034aaa-a838-11e9-a2fc-000d3a38a36f                          2.00
# 000be838-85df-11ea-a90b-000d3a38a36f                          1.00
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f                          4.00
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f                          2.00
#
#                                       customer_value_total_ever_offline  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f                             427.19
# 00034aaa-a838-11e9-a2fc-000d3a38a36f                             150.48
# 000be838-85df-11ea-a90b-000d3a38a36f                             365.72
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f                             531.19
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f                             299.98
#
#                                       customer_value_total_ever_online  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f                            348.88
# 00034aaa-a838-11e9-a2fc-000d3a38a36f                            118.99
# 000be838-85df-11ea-a90b-000d3a38a36f                            356.97
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f                            342.97
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f                           1320.35
#
#                                                        interested_in_categories_12  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f                     [ERKEK, COCUK, AKTIFSPOR]
# 00034aaa-a838-11e9-a2fc-000d3a38a36f                                [ERKEK, KADIN]
# 000be838-85df-11ea-a90b-000d3a38a36f                       [AKTIFCOCUK, AKTIFSPOR]
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f  [AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f                            [ERKEK, AKTIFSPOR]
#
#                                       order_num_total_ever_omnichannel  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f                              5.00
# 00034aaa-a838-11e9-a2fc-000d3a38a36f                              3.00
# 000be838-85df-11ea-a90b-000d3a38a36f                              4.00
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f                              7.00
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f                              7.00
#
#                                       customer_value_total_ever_omnichannel
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f                                 776.07
# 00034aaa-a838-11e9-a2fc-000d3a38a36f                                 269.47
# 000be838-85df-11ea-a90b-000d3a38a36f                                 722.69
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f                                 874.16
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f                                1620.33

# %%
sale_df = pd.DataFrame()
sale_df = customers_for_sales[(customers_for_sales["segment"].isin(["cant_loose","atrisk","hibernating","new_customers"]))]

# %%
sale_df.head()
# Out:
#                                       recency  frequency  monetary  \
# master_id
# 00034aaa-a838-11e9-a2fc-000d3a38a36f 298 days       3.00    269.47
# 00263f1a-210a-11ea-b50a-000d3a38a36f 362 days       3.00    501.94
# 0033f078-7359-11ea-92d0-000d3a38a36f 360 days       2.00    153.98
# 006bb20e-a9a8-11e9-a2fc-000d3a38a36f 188 days       3.00    620.41
# 007cdfe4-1f54-11ea-87bf-000d3a38a36f 355 days       8.00    778.88
#
#                                      recency_score frequency_score  \
# master_id
# 00034aaa-a838-11e9-a2fc-000d3a38a36f             1               2
# 00263f1a-210a-11ea-b50a-000d3a38a36f             1               2
# 0033f078-7359-11ea-92d0-000d3a38a36f             1               1
# 006bb20e-a9a8-11e9-a2fc-000d3a38a36f             2               2
# 007cdfe4-1f54-11ea-87bf-000d3a38a36f             1               5
#
#                                      monetary_score RF_SCORE      segment  \
# master_id
# 00034aaa-a838-11e9-a2fc-000d3a38a36f              1       12  hibernating
# 00263f1a-210a-11ea-b50a-000d3a38a36f              3       12  hibernating
# 0033f078-7359-11ea-92d0-000d3a38a36f              1       11  hibernating
# 006bb20e-a9a8-11e9-a2fc-000d3a38a36f              3       22  hibernating
# 007cdfe4-1f54-11ea-87bf-000d3a38a36f              4       15   cant_loose
#
#                                      order_channel last_order_channel  \
# master_id
# 00034aaa-a838-11e9-a2fc-000d3a38a36f       Desktop            Offline
# 00263f1a-210a-11ea-b50a-000d3a38a36f   Android App        Android App
# 0033f078-7359-11ea-92d0-000d3a38a36f   Android App        Android App
# 006bb20e-a9a8-11e9-a2fc-000d3a38a36f   Android App            Offline
# 007cdfe4-1f54-11ea-87bf-000d3a38a36f   Android App        Android App
#
#                                      first_order_date last_order_date  \
# master_id
# 00034aaa-a838-11e9-a2fc-000d3a38a36f       2015-11-09      2020-08-07
# 00263f1a-210a-11ea-b50a-000d3a38a36f       2019-08-04      2020-06-04
# 0033f078-7359-11ea-92d0-000d3a38a36f       2019-12-08      2020-06-06
# 006bb20e-a9a8-11e9-a2fc-000d3a38a36f       2017-01-14      2020-11-25
# 007cdfe4-1f54-11ea-87bf-000d3a38a36f       2019-11-21      2020-06-11
#
#                                      last_order_date_online  \
# master_id
# 00034aaa-a838-11e9-a2fc-000d3a38a36f             2015-11-09
# 00263f1a-210a-11ea-b50a-000d3a38a36f             2020-06-04
# 0033f078-7359-11ea-92d0-000d3a38a36f             2020-06-06
# 006bb20e-a9a8-11e9-a2fc-000d3a38a36f             2020-04-28
# 007cdfe4-1f54-11ea-87bf-000d3a38a36f             2020-06-11
#
#                                      last_order_date_offline  \
# master_id
# 00034aaa-a838-11e9-a2fc-000d3a38a36f              2020-08-07
# 00263f1a-210a-11ea-b50a-000d3a38a36f              2019-09-26
# 0033f078-7359-11ea-92d0-000d3a38a36f              2019-12-08
# 006bb20e-a9a8-11e9-a2fc-000d3a38a36f              2020-11-25
# 007cdfe4-1f54-11ea-87bf-000d3a38a36f              2020-03-05
#
#                                       order_num_total_ever_online  \
# master_id
# 00034aaa-a838-11e9-a2fc-000d3a38a36f                         1.00
# 00263f1a-210a-11ea-b50a-000d3a38a36f                         1.00
# 0033f078-7359-11ea-92d0-000d3a38a36f                         1.00
# 006bb20e-a9a8-11e9-a2fc-000d3a38a36f                         2.00
# 007cdfe4-1f54-11ea-87bf-000d3a38a36f                         2.00
#
#                                       order_num_total_ever_offline  \
# master_id
# 00034aaa-a838-11e9-a2fc-000d3a38a36f                          2.00
# 00263f1a-210a-11ea-b50a-000d3a38a36f                          2.00
# 0033f078-7359-11ea-92d0-000d3a38a36f                          1.00
# 006bb20e-a9a8-11e9-a2fc-000d3a38a36f                          1.00
# 007cdfe4-1f54-11ea-87bf-000d3a38a36f                          6.00
#
#                                       customer_value_total_ever_offline  \
# master_id
# 00034aaa-a838-11e9-a2fc-000d3a38a36f                             150.48
# 00263f1a-210a-11ea-b50a-000d3a38a36f                             309.95
# 0033f078-7359-11ea-92d0-000d3a38a36f                              99.99
# 006bb20e-a9a8-11e9-a2fc-000d3a38a36f                             214.46
# 007cdfe4-1f54-11ea-87bf-000d3a38a36f                             618.90
#
#                                       customer_value_total_ever_online  \
# master_id
# 00034aaa-a838-11e9-a2fc-000d3a38a36f                            118.99
# 00263f1a-210a-11ea-b50a-000d3a38a36f                            191.99
# 0033f078-7359-11ea-92d0-000d3a38a36f                             53.99
# 006bb20e-a9a8-11e9-a2fc-000d3a38a36f                            405.95
# 007cdfe4-1f54-11ea-87bf-000d3a38a36f                            159.98
#
#                                      interested_in_categories_12  \
# master_id
# 00034aaa-a838-11e9-a2fc-000d3a38a36f              [ERKEK, KADIN]
# 00263f1a-210a-11ea-b50a-000d3a38a36f                     [ERKEK]
# 0033f078-7359-11ea-92d0-000d3a38a36f                     [ERKEK]
# 006bb20e-a9a8-11e9-a2fc-000d3a38a36f          [ERKEK, AKTIFSPOR]
# 007cdfe4-1f54-11ea-87bf-000d3a38a36f                     [ERKEK]
#
#                                       order_num_total_ever_omnichannel  \
# master_id
# 00034aaa-a838-11e9-a2fc-000d3a38a36f                              3.00
# 00263f1a-210a-11ea-b50a-000d3a38a36f                              3.00
# 0033f078-7359-11ea-92d0-000d3a38a36f                              2.00
# 006bb20e-a9a8-11e9-a2fc-000d3a38a36f                              3.00
# 007cdfe4-1f54-11ea-87bf-000d3a38a36f                              8.00
#
#                                       customer_value_total_ever_omnichannel
# master_id
# 00034aaa-a838-11e9-a2fc-000d3a38a36f                                 269.47
# 00263f1a-210a-11ea-b50a-000d3a38a36f                                 501.94
# 0033f078-7359-11ea-92d0-000d3a38a36f                                 153.98
# 006bb20e-a9a8-11e9-a2fc-000d3a38a36f                                 620.41
# 007cdfe4-1f54-11ea-87bf-000d3a38a36f                                 778.88

# %%
sale_df["segment"].value_counts()
# Out:
# hibernating      1785
# cant_loose        814
# new_customers     171
# Name: segment, dtype: int64

# %%
sale_df["interested_in_categories_12"].value_counts()
# Out:
# [ERKEK]                                         740
# [ERKEK, AKTIFSPOR]                              284
# [ERKEK, KADIN]                                  266
# [COCUK]                                         245
# [AKTIFCOCUK]                                    199
# [ERKEK, KADIN, AKTIFSPOR]                       154
# [COCUK, KADIN]                                  127
# [AKTIFCOCUK, COCUK]                              84
# [COCUK, AKTIFSPOR]                               69
# [AKTIFCOCUK, AKTIFSPOR]                          66
# [ERKEK, COCUK]                                   48
# [ERKEK, COCUK, KADIN]                            44
# [AKTIFCOCUK, COCUK, KADIN]                       41
# [ERKEK, COCUK, KADIN, AKTIFSPOR]                 41
# [COCUK, KADIN, AKTIFSPOR]                        37
# [AKTIFCOCUK, KADIN]                              37
# [AKTIFCOCUK, COCUK, AKTIFSPOR]                   32
# [AKTIFCOCUK, KADIN, AKTIFSPOR]                   30
# [AKTIFCOCUK, COCUK, KADIN, AKTIFSPOR]            29
# [AKTIFCOCUK, ERKEK, COCUK]                       28
# [AKTIFCOCUK, ERKEK, AKTIFSPOR]                   26
# [AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]     25
# [AKTIFCOCUK, ERKEK, KADIN, AKTIFSPOR]            24
# [AKTIFCOCUK, ERKEK]                              21
# [AKTIFCOCUK, ERKEK, COCUK, KADIN]                20
# [ERKEK, COCUK, AKTIFSPOR]                        20
# [AKTIFCOCUK, ERKEK, KADIN]                       18
# [AKTIFCOCUK, ERKEK, COCUK, AKTIFSPOR]            15
# Name: interested_in_categories_12, dtype: int64

# %%
save_df = pd.DataFrame()
save_df["customer_id_for_sales"] = sale_df.index
save_df.to_csv("sale_maleOrChildren_customers.csv",index=False)

# %% [markdown]
# # BONUS: Functionize

# %%
def create_rfm(dataframe):
    # PREPROCESS
    dataframe["order_num_total"] = dataframe["order_num_total_ever_online"]+dataframe["order_num_total_ever_offline"]
    dataframe["customer_value_total"] =  dataframe["customer_value_total_ever_online"]+ dataframe["customer_value_total_ever_offline"]
    date_columns = dataframe.columns[dataframe.columns.str.contains("date")]
    dataframe[date_columns] = dataframe[date_columns].apply(pd.to_datetime)
    #RFM
    dataframe["last_order_date"].max() # 2021-50-30
    analysis_date = dt.datetime(2021,6,1)
    rfm = pd.DataFrame()
    rfm["customer_id"] = dataframe["master_id"]
    rfm["recency"] = (analysis_date - dataframe["last_order_date"]).astype('timedelta64[D]')
    rfm["frequency"] = dataframe["order_num_total"]
    rfm["monetary"] = dataframe["customer_value_total"]
    #RF vand RFM scores
    rfm["recency_score"] = pd.qcut(rfm['recency'],5,labels=[5,4,3,2,1])
    rfm["frequency_score"] = pd.qcut(rfm['frequency'].rank(method="first"),5,labels=[1,2,3,4,5])
    rfm["monetary_score"] = pd.qcut(rfm['monetary'],5,labels=[1,2,3,4,5])
    rfm["RF_SCORE"] = (rfm["recency_score"].astype(str) + rfm["frequency_score"].astype(str))
    rfm["RFM_SCORE"] = (rfm["recency_score"].astype(str) + rfm["frequency_score"].astype(str) + rfm["monetary_score"].astype(str))
    #SEGMENTATION
    seg_map = {
        r'[1-2][1-2]': 'hibernating',
        r'[1-2][3-4]': 'at_Risk',
        r'[1-2]5': 'cant_loose',
        r'3[1-2]': 'about_to_sleep',
        r'33': 'need_attention',
        r'[3-4][4-5]': 'loyal_customers',
        r'41': 'promising',
        r'51': 'new_customers',
        r'[4-5][2-3]': 'potential_loyalists',
        r'5[4-5]': 'champions'
    }
    rfm['segment'] = rfm["RF_SCORE"].replace(seg_map,regex=True)

    return rfm[["customer_id","RF_SCORE","RFM_SCORE","segment"]]

# %%
flo_data_.columns
# Out:
# Index(['master_id', 'order_channel', 'last_order_channel', 'first_order_date',
#        'last_order_date', 'last_order_date_online', 'last_order_date_offline',
#        'order_num_total_ever_online', 'order_num_total_ever_offline',
#        'customer_value_total_ever_offline', 'customer_value_total_ever_online',
#        'interested_in_categories_12', 'order_num_total',
#        'customer_value_total'],
#       dtype='object')

# %%
rfm_df = create_rfm(flo_data_)

# %%
rfm_df
# Out:
#                                 customer_id RF_SCORE RFM_SCORE  \
# 0      cc294636-19f0-11eb-8d74-000d3a38a36f       34       344
# 1      f431bd5a-ab7b-11e9-a2fc-000d3a38a36f       35       355
# 2      69b69676-1a40-11ea-941b-000d3a38a36f       24       243
# 3      1854e56c-491f-11eb-806e-000d3a38a36f       31       311
# 4      d6ea1074-f1f5-11e9-9346-000d3a38a36f       31       311
# ...                                     ...      ...       ...
# 19940  727e2b6e-ddd4-11e9-a848-000d3a38a36f       13       132
# 19941  25cd53d4-61bf-11ea-8dd8-000d3a38a36f       22       222
# 19942  8aea4c2a-d6fc-11e9-93bc-000d3a38a36f       53       533
# 19943  e50bb46c-ff30-11e9-a5e8-000d3a38a36f       34       344
# 19944  740998d2-b1f7-11e9-89fa-000d3a38a36f       12       121
#
#                    segment
# 0          loyal_customers
# 1          loyal_customers
# 2                  at_Risk
# 3           about_to_sleep
# 4           about_to_sleep
# ...                    ...
# 19940              at_Risk
# 19941          hibernating
# 19942  potential_loyalists
# 19943      loyal_customers
# 19944          hibernating
#
# [19945 rows x 4 columns]
