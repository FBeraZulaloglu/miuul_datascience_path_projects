# %% [markdown]
# # **Rating Product & Sorting Reviews in Amazon**

# %% [markdown]
# ## Problem <br>
# In e-commerce sorting reviews correctly and avoiding the reviews that are not relatable or that can lead misinformation about the products are very important. So, if misleading reviews take the lead in reviews it will effect the e-commerce site in a bad way because customers will not be happy with that situation. The other important point in e-commerce is rating products. We are going to cover these problems with amazon dataset.

# %%
import pandas as pd
import scipy.stats as st
from sklearn.preprocessing import MinMaxScaler

# %%
amazon_df = pd.read_csv("amazon_review.csv")
df = amazon_df.copy()
df.head()
# Out:
#        reviewerID        asin  reviewerName helpful  \
# 0  A3SBTW3WS4IQSN  B007WTAJTO           NaN  [0, 0]
# 1  A18K1ODH1I2MVB  B007WTAJTO          0mie  [0, 0]
# 2  A2FII3I2MBMUIA  B007WTAJTO           1K3  [0, 0]
# 3   A3H99DFEG68SR  B007WTAJTO           1m2  [0, 0]
# 4  A375ZM4U047O79  B007WTAJTO  2&amp;1/2Men  [0, 0]
#
#                                           reviewText  overall  \
# 0                                         No issues.      4.0
# 1  Purchased this for my device, it worked as adv...      5.0
# 2  it works as expected. I should have sprung for...      4.0
# 3  This think has worked out great.Had a diff. br...      5.0
# 4  Bought it with Retail Packaging, arrived legit...      5.0
#
#                                   summary  unixReviewTime  reviewTime  \
# 0                              Four Stars      1406073600  2014-07-23
# 1                           MOAR SPACE!!!      1382659200  2013-10-25
# 2               nothing to really say....      1356220800  2012-12-23
# 3  Great buy at this price!!!  *** UPDATE      1384992000  2013-11-21
# 4                        best deal around      1373673600  2013-07-13
#
#    day_diff  helpful_yes  total_vote
# 0       138            0           0
# 1       409            0           0
# 2       715            0           0
# 3       382            0           0
# 4       513            0           0

# %% [markdown]
# ## Task1: Calculate Average Rating To Current Reviews and Compare to Average Rating For All Reviews

# %%
def check_df(dataframe, count=5):
    print("--------------------- Shape ---------------------")
    print(dataframe.shape)
    print("--------------------- Types ---------------------")
    print(dataframe.dtypes)
    print("--------------------- Head ---------------------")
    print(dataframe.head(count))
    print("--------------------- Tail ---------------------")
    print(dataframe.tail(count))
    print("--------------------- NA ---------------------")
    print(dataframe.isnull().sum())
    print("-------------------- Quantiles ---------------------")
    print(dataframe.describe([0, 0.05, 0.50, 0.95, 0.99, 1]).T)

# %%
## All reviews are just one product
df["asin"].value_counts()
# Out:
# B007WTAJTO    4915
# Name: asin, dtype: int64

# %%
df.loc[df["day_diff"]<100,"overall"].mean()
# Out:
# 4.749049429657795

# %%
df["overall"].mean()
# Out:
# 4.587589013224822

# %%
df["day_diff"].quantile(0.25)
# Out:
# 281.0

# %%
def control_different_timespan(df):
    print("AVERAGE RATINGS FOR DIFFERENT TIMESTAMPS")
    print("The reviews has been made...")
    print(f"First",df["day_diff"].quantile(0.25),"days after getting product.")
    print(df.loc[df["day_diff"]<= df["day_diff"].quantile(0.25),"overall"].mean())
    print(f"Between",df["day_diff"].quantile(0.25),"and",df["day_diff"].quantile(0.50),"days after getting product.")
    print(df.loc[(df["day_diff"]> df["day_diff"].quantile(0.25)) & (df["day_diff"]<= df["day_diff"].quantile(0.50)),"overall"].mean())
    print(f"Between",df["day_diff"].quantile(0.50),"and",df["day_diff"].quantile(0.75),"days after getting product.")
    print(df.loc[(df["day_diff"]> df["day_diff"].quantile(0.50)) & (df["day_diff"]<= df["day_diff"].quantile(0.75)),"overall"].mean())
    print(f"After",df["day_diff"].quantile(0.75),"days after getting product.")
    print(df.loc[df["day_diff"]> df["day_diff"].quantile(0.75),"overall"].mean())

# %%
control_different_timespan(df)
# Out:
# AVERAGE RATINGS FOR DIFFERENT TIMESTAMPS
# The reviews has been made...
# First 281.0 days after getting product.
# 4.6957928802588995
# Between 281.0 and 431.0 days after getting product.
# 4.636140637775961
# Between 431.0 and 601.0 days after getting product.
# 4.571661237785016
# After 601.0 days after getting product.
# 4.4462540716612375

# %% [markdown]
# **Result:** The day difference after getting a product effects the ratings of the product. If you rate your product after ~280 days then your opionon about the product will change little bit and effect your rating values decreasing.

# %% [markdown]
# ## Task2: Decide 20 top reviews to show on a website or app.

# %% [markdown]
# ### Step1: Create "helpful_no" variable

# %% [markdown]
# * total_vote = up down count
# * up = helpful_yes
# * helpful_no = total_vote - helpful_yes

# %%
df["helpful_no"] = df["total_vote"] - df['helpful_yes']

# %%
df["helpful_no"].value_counts()
# Out:
# 0      4674
# 1       175
# 2        43
# 3         7
# 27        2
# 4         2
# 6         2
# 73        1
# 8         1
# 10        1
# 68        1
# 110       1
# 183       1
# 77        1
# 126       1
# 14        1
# 9         1
# Name: helpful_no, dtype: int64

# %% [markdown]
# ### Step2: Add score_pos_neg_diff, score_average_rating and wilson_lower_bound scores to dataframe.

# %% [markdown]
# * Define **score_pos_neg_diff**, **score_average_rating** and **wilson_lower_bound** functions to calculate the values.
# * Create **score_pos_neg_diff** column while using its funciton to calculate values.
# * Create **score_average_rating** column while using its funciton to calculate values.
# * Create **wilson_lower_bound** column while using its funciton to calculate values.

# %%
import math

def score_pos_neg_diff(up, down):
    return up - down


def score_average_rating(up, down):
    if up + down == 0:
        return 0
    return up / (up + down)

def wilson_lower_bound(up, down, confidence=0.95):
    n = up + down
    if n == 0:
        return 0
    z = st.norm.ppf(1 - (1 - confidence) / 2)
    phat = 1.0 * up / n
    return (phat + z * z / (2 * n) - z * math.sqrt((phat * (1 - phat) + z * z / (4 * n)) / n)) / (1 + z * z / n)

# %%
df["score_pos_neg_diff"] = score_pos_neg_diff(df["helpful_yes"],df["helpful_no"])
df.sort_values("score_pos_neg_diff",ascending=False).head(20)
# Out:
#           reviewerID        asin                 reviewerName       helpful  \
# 2031  A12B7ZMXFI6IXY  B007WTAJTO         Hyoun Kim "Faluzure"  [1952, 2020]
# 4212   AVBMZZAFEKO58  B007WTAJTO                  SkincareCEO  [1568, 1694]
# 3449   AOEAD7DPLZE53  B007WTAJTO            NLee the Engineer  [1428, 1505]
# 317   A1ZQAQFYSXL5MQ  B007WTAJTO      Amazon Customer "Kelly"    [422, 495]
# 3981  A1K91XXQ6ZEBQR  B007WTAJTO   R. Sutton, Jr. "RWSynergy"    [112, 139]
# 4596  A1WTQUOQ4WG9AI  B007WTAJTO  Tom Henriksen "Doggy Diner"     [82, 109]
# 1835  A1J6VSUM80UAF8  B007WTAJTO                  goconfigure      [60, 68]
# 4672  A2DKQQIZ793AV5  B007WTAJTO                      Twister      [45, 49]
# 4306   AOHXKM5URSKAB  B007WTAJTO                Stellar Eller      [51, 65]
# 315   A2J26NNQX6WKAU  B007WTAJTO   Amazon Customer "johncrea"      [38, 48]
# 3807   AFGRMORWY2QNX  B007WTAJTO                   R. Heisler      [22, 25]
# 4302  A2EL2GWJ9T0DWY  B007WTAJTO                    Stayeraug      [14, 16]
# 93     A837QPVOZ9YAD  B007WTAJTO                      Airedad      [15, 21]
# 1609  A2TPXOZSU1DACQ  B007WTAJTO                       Eskimo        [7, 7]
# 1465   A6I8KXYK24RTB  B007WTAJTO                     D. Stein        [7, 7]
# 4072  A22GOZTFA02O2F  B007WTAJTO                  sb21 "sb21"        [6, 6]
# 2268   A680RUE1FDO8B  B007WTAJTO             Jerry Saperstein       [8, 10]
# 121   A2Z4VVF1NTJWPB  B007WTAJTO                       A. Lee        [5, 5]
# 323   A15X60NOGL3WDW  B007WTAJTO       Amazon Customer "Milo"        [6, 7]
# 2695  A1Y6RTMK10TWWF  B007WTAJTO                    kinematic        [6, 7]
#
#                                              reviewText  overall  \
# 2031  [[ UPDATE - 6/19/2014 ]]So my lovely wife boug...      5.0
# 4212  NOTE:  please read the last update (scroll to ...      1.0
# 3449  I have tested dozens of SDHC and micro-SDHC ca...      5.0
# 317   If your card gets hot enough to be painful, it...      1.0
# 3981  The last few days I have been diligently shopp...      5.0
# 4596  Hi:I ordered two card and they arrived the nex...      1.0
# 1835  Bought from BestBuy online the day it was anno...      5.0
# 4672  Sandisk announcement of the first 128GB micro ...      5.0
# 4306  While I got this card as a "deal of the day" o...      5.0
# 315   Bought this card to use with my Samsung Galaxy...      5.0
# 3807  I bought this card to replace a lost 16 gig in...      3.0
# 4302  So I got this SD specifically for my GoPro Bla...      5.0
# 93    I'm amazed.  I ordered this from Amazon on Tue...      5.0
# 1609  I have always been a sandisk guy.  This cards ...      5.0
# 1465  I for one have not bought into Google's, or an...      4.0
# 4072  I used this for my Samsung Galaxy Tab 2 7.0 . ...      5.0
# 2268  My Samsung Galaxy S4 now has 119GB of fast mic...      5.0
# 121   Update: providing an update with regard to San...      5.0
# 323   I replaced a 64GB card in my note 3 with this ...      5.0
# 2695  did not work when first inserted into my samsu...      5.0
#
#                                                 summary  unixReviewTime  \
# 2031  UPDATED - Great w/ Galaxy S4 & Galaxy Tab 4 10...      1367366400
# 4212  1 Star reviews - Micro SDXC card unmounts itse...      1375660800
# 3449  Top of the class among all (budget-priced) mic...      1348617600
# 317                                 Warning, read this!      1346544000
# 3981  Resolving confusion between "Mobile Ultra" and...      1350864000
# 4596     Designed incompatibility/Don't support SanDisk      1348272000
# 1835                                           I own it      1393545600
# 4672  Super high capacity!!!  Excellent price (on Am...      1394150400
# 4306                                      Awesome Card!      1339200000
# 315   Samsung Galaxy Tab2 works with this card if re...      1344816000
# 3807   Good buy for the money but wait, I had an issue!      1361923200
# 4302                        Perfect with GoPro Black 3+      1395360000
# 93    Very fast class 10 card - and excellent servic...      1343174400
# 1609                  Bet you wish you had one of these      1395792000
# 1465                                           Finally.      1397433600
# 4072               Used for my Samsung Galaxy Tab 2 7.0      1347321600
# 2268                      Incredible simply incredible.      1395014400
# 121                      ready for use on the Galaxy S3      1346803200
# 323                           Working fine in my Note 3      1396310400
# 2695  Works in Samsung Galaxy Tab 2 10.1 after forma...      1347062400
#
#       reviewTime  day_diff  helpful_yes  total_vote  helpful_no  \
# 2031  2013-01-05       702         1952        2020          68
# 4212  2013-05-08       579         1568        1694         126
# 3449  2012-09-26       803         1428        1505          77
# 317   2012-02-09      1033          422         495          73
# 3981  2012-10-22       777          112         139          27
# 4596  2012-09-22       807           82         109          27
# 1835  2014-02-28       283           60          68           8
# 4672  2014-07-03       158           45          49           4
# 4306  2012-09-06       823           51          65          14
# 315   2012-08-13       847           38          48          10
# 3807  2013-02-27       649           22          25           3
# 4302  2014-03-21       262           14          16           2
# 93    2012-07-25       866           15          21           6
# 1609  2014-03-26       257            7           7           0
# 1465  2014-04-14       238            7           7           0
# 4072  2012-11-09       759            6           6           0
# 2268  2014-03-17       266            8          10           2
# 121   2012-05-09       943            5           5           0
# 323   2014-01-04       338            6           7           1
# 2695  2012-08-09       851            6           7           1
#
#       score_pos_neg_diff
# 2031                1884
# 4212                1442
# 3449                1351
# 317                  349
# 3981                  85
# 4596                  55
# 1835                  52
# 4672                  41
# 4306                  37
# 315                   28
# 3807                  19
# 4302                  12
# 93                     9
# 1609                   7
# 1465                   7
# 4072                   6
# 2268                   6
# 121                    5
# 323                    5
# 2695                   5

# %%
df["score_average_rating"] = df.apply(lambda x: score_average_rating(x["helpful_yes"],x["helpful_no"]),axis=1)
df.sort_values("score_average_rating",ascending=False).head(20)
# Out:
#           reviewerID        asin                 reviewerName helpful  \
# 4277  A35KXSU6AD1481  B007WTAJTO                        S. Q.  [1, 1]
# 2881  A3VSG5X7GPNNW6  B007WTAJTO                   Lou Thomas  [1, 1]
# 1073  A2ZXEKQ2OBZLEE  B007WTAJTO                   C. Sanchez  [1, 1]
# 445    AIWBDRNBODLEA  B007WTAJTO           Apache "Elizabeth"  [1, 1]
# 3923   A2PH4RGYVR34L  B007WTAJTO              Rock Your Roots  [1, 1]
# 435    AUH8I22ITG020  B007WTAJTO               Anthony L cate  [1, 1]
# 2901  A28TRYU3FJ039C  B007WTAJTO                         luis  [1, 1]
# 2204   AANX2UN8NPE22  B007WTAJTO                jbwam "jbwam"  [1, 1]
# 2206  A3KO3964CNP0XN  B007WTAJTO                      JCBiker  [1, 1]
# 3408  A20WUUD9EDWY4N  B007WTAJTO         Neng Vang "Neng2012"  [1, 1]
# 4538  A2AF4ZAORAOI04  B007WTAJTO                       Tim ha  [1, 1]
# 1097  A28I19GM9HQ7IS  B007WTAJTO          Cyrus C. Cha "moss"  [1, 1]
# 2885  A3ABVT2M5M6IKE  B007WTAJTO   L. P. Nugaliyadda "Pramod"  [1, 1]
# 3418  A2IL8EBLBZJUEG  B007WTAJTO               Ni'anhel Moore  [1, 1]
# 4554  A202CZ4PJH83G4  B007WTAJTO                      Tinfoot  [1, 1]
# 1609  A2TPXOZSU1DACQ  B007WTAJTO                       Eskimo  [7, 7]
# 402   A342LSQCE5UESO  B007WTAJTO  Andrew R. Seiler "bookfish"  [1, 1]
# 2226   AZKN9KO2ECFFZ  B007WTAJTO                         JEFE  [1, 1]
# 3901  A15ADZE1K9839O  B007WTAJTO     Roberto K. Cho "chorobe"  [1, 1]
# 3897  A3DSXJDE6PAXHZ  B007WTAJTO      Robert K. Harvey "BobH"  [1, 1]
#
#                                              reviewText  overall  \
# 4277  I have a galaxy note II and after rooting I no...      5.0
# 2881  The Nexus One is listed as supporting a maximu...      5.0
# 1073  I used it with my Samsung S4 and it works grea...      5.0
# 445   This is exactly what I was looking for to upgr...      4.0
# 3923  It's a SanDisk, so what more is there to say? ...      5.0
# 435   This is working great in my AT&T Galaxy Note. ...      5.0
# 2901  Not a good typer or speller :) here is what I ...      5.0
# 2204  I just called Sandisk and they say they have a...      2.0
# 2206  I bought this for my garmin virb action cam.  ...      5.0
# 3408  Very good card and still working now in my car...      5.0
# 4538  There is a speed penalty if exfat is used as o...      4.0
# 1097  My wife and I just upgraded our phone to Note ...      4.0
# 2885  Superb! No complains what so ever. I bought th...      5.0
# 3418  There's really not much to say. I put it right...      5.0
# 4554  Has worked like an absolute charm in my PSP, a...      5.0
# 1609  I have always been a sandisk guy.  This cards ...      5.0
# 402   Arrived in manufacturers packaging so it looke...      5.0
# 2226  Put this in the Samsung S5.  Works great.  sto...      5.0
# 3901  UPDATE:I raised my star rating on this from 1 ...      4.0
# 3897  Its going back because it doesn't meet spec.Te...      2.0
#
#                                                 summary  unixReviewTime  \
# 4277                                          Perfect!!      1355875200
# 2881                         Nexus One Loves This Card!      1349049600
# 1073                            Tons of space for phone      1376352000
# 445                                 Amazon Great Prices      1387324800
# 3923                                  What more to say?      1388361600
# 435                              Love the extra storage      1343088000
# 2901                          Awesome and fast  card :)      1368403200
# 2204  Sandisk will replace failures due to bad batch...      1371168000
# 2206                                         Great card      1383177600
# 3408                                 working no problem      1374710400
# 4538                Decent speed for the card this size      1398384000
# 1097                              More space for Note 3      1381708800
# 2885                                         Excellent!      1395360000
# 3418                                        Works Great      1388448000
# 4554                                           PSP 3000      1391817600
# 1609                  Bet you wish you had one of these      1395792000
# 402                    great, works well with galaxy s3      1348531200
# 2226                                       great memory      1402876800
# 3901   Good while it lasted! BUT good customer support!      1363737600
# 3897                                   Poor write speed      1385510400
#
#       reviewTime  day_diff  helpful_yes  total_vote  helpful_no  \
# 4277  2012-12-19       719            1           1           0
# 2881  2012-01-10      1063            1           1           0
# 1073  2013-08-13       482            1           1           0
# 445   2013-12-18       355            1           1           0
# 3923  2013-12-30       343            1           1           0
# 435   2012-07-24       867            1           1           0
# 2901  2013-05-13       574            1           1           0
# 2204  2013-06-14       542            1           1           0
# 2206  2013-10-31       403            1           1           0
# 3408  2013-07-25       501            1           1           0
# 4538  2014-04-25       227            1           1           0
# 1097  2013-10-14       420            1           1           0
# 2885  2014-03-21       262            1           1           0
# 3418  2013-12-31       342            1           1           0
# 4554  2014-08-02       128            1           1           0
# 1609  2014-03-26       257            7           7           0
# 402   2012-09-25       804            1           1           0
# 2226  2014-06-16       175            1           1           0
# 3901  2013-03-20       628            1           1           0
# 3897  2013-11-27       376            1           1           0
#
#       score_pos_neg_diff  score_average_rating
# 4277                   1                   1.0
# 2881                   1                   1.0
# 1073                   1                   1.0
# 445                    1                   1.0
# 3923                   1                   1.0
# 435                    1                   1.0
# 2901                   1                   1.0
# 2204                   1                   1.0
# 2206                   1                   1.0
# 3408                   1                   1.0
# 4538                   1                   1.0
# 1097                   1                   1.0
# 2885                   1                   1.0
# 3418                   1                   1.0
# 4554                   1                   1.0
# 1609                   7                   1.0
# 402                    1                   1.0
# 2226                   1                   1.0
# 3901                   1                   1.0
# 3897                   1                   1.0

# %%
df["wilson_lower_bound"] = df.apply(lambda x: wilson_lower_bound(x["helpful_yes"],x["helpful_no"]),axis=1)
df.sort_values("wilson_lower_bound",ascending=False).head(20)
# Out:
#           reviewerID        asin                          reviewerName  \
# 2031  A12B7ZMXFI6IXY  B007WTAJTO                  Hyoun Kim "Faluzure"
# 3449   AOEAD7DPLZE53  B007WTAJTO                     NLee the Engineer
# 4212   AVBMZZAFEKO58  B007WTAJTO                           SkincareCEO
# 317   A1ZQAQFYSXL5MQ  B007WTAJTO               Amazon Customer "Kelly"
# 4672  A2DKQQIZ793AV5  B007WTAJTO                               Twister
# 1835  A1J6VSUM80UAF8  B007WTAJTO                           goconfigure
# 3981  A1K91XXQ6ZEBQR  B007WTAJTO            R. Sutton, Jr. "RWSynergy"
# 3807   AFGRMORWY2QNX  B007WTAJTO                            R. Heisler
# 4306   AOHXKM5URSKAB  B007WTAJTO                         Stellar Eller
# 4596  A1WTQUOQ4WG9AI  B007WTAJTO           Tom Henriksen "Doggy Diner"
# 315   A2J26NNQX6WKAU  B007WTAJTO            Amazon Customer "johncrea"
# 1465   A6I8KXYK24RTB  B007WTAJTO                              D. Stein
# 1609  A2TPXOZSU1DACQ  B007WTAJTO                                Eskimo
# 4302  A2EL2GWJ9T0DWY  B007WTAJTO                             Stayeraug
# 4072  A22GOZTFA02O2F  B007WTAJTO                           sb21 "sb21"
# 1072  A2O96COBMVY9C4  B007WTAJTO                        Crysis Complex
# 2583  A3MEPYZVTAV90W  B007WTAJTO                               J. Wong
# 121   A2Z4VVF1NTJWPB  B007WTAJTO                                A. Lee
# 1142  A1PLHPPAJ5MUXG  B007WTAJTO  Daniel Pham(Danpham_X @ yahoo.  com)
# 1753   ALPLKR59QMBUX  B007WTAJTO                             G. Becker
#
#            helpful                                         reviewText  \
# 2031  [1952, 2020]  [[ UPDATE - 6/19/2014 ]]So my lovely wife boug...
# 3449  [1428, 1505]  I have tested dozens of SDHC and micro-SDHC ca...
# 4212  [1568, 1694]  NOTE:  please read the last update (scroll to ...
# 317     [422, 495]  If your card gets hot enough to be painful, it...
# 4672      [45, 49]  Sandisk announcement of the first 128GB micro ...
# 1835      [60, 68]  Bought from BestBuy online the day it was anno...
# 3981    [112, 139]  The last few days I have been diligently shopp...
# 3807      [22, 25]  I bought this card to replace a lost 16 gig in...
# 4306      [51, 65]  While I got this card as a "deal of the day" o...
# 4596     [82, 109]  Hi:I ordered two card and they arrived the nex...
# 315       [38, 48]  Bought this card to use with my Samsung Galaxy...
# 1465        [7, 7]  I for one have not bought into Google's, or an...
# 1609        [7, 7]  I have always been a sandisk guy.  This cards ...
# 4302      [14, 16]  So I got this SD specifically for my GoPro Bla...
# 4072        [6, 6]  I used this for my Samsung Galaxy Tab 2 7.0 . ...
# 1072        [5, 5]  What more can I say? The 64GB micro SD works f...
# 2583        [5, 5]  I bought this Class 10 SD card for my GoPro 3 ...
# 121         [5, 5]  Update: providing an update with regard to San...
# 1142        [5, 5]  As soon as I saw that this card was announced ...
# 1753        [5, 5]  Puchased this card right after I received my S...
#
#       overall                                            summary  \
# 2031      5.0  UPDATED - Great w/ Galaxy S4 & Galaxy Tab 4 10...
# 3449      5.0  Top of the class among all (budget-priced) mic...
# 4212      1.0  1 Star reviews - Micro SDXC card unmounts itse...
# 317       1.0                                Warning, read this!
# 4672      5.0  Super high capacity!!!  Excellent price (on Am...
# 1835      5.0                                           I own it
# 3981      5.0  Resolving confusion between "Mobile Ultra" and...
# 3807      3.0   Good buy for the money but wait, I had an issue!
# 4306      5.0                                      Awesome Card!
# 4596      1.0     Designed incompatibility/Don't support SanDisk
# 315       5.0  Samsung Galaxy Tab2 works with this card if re...
# 1465      4.0                                           Finally.
# 1609      5.0                  Bet you wish you had one of these
# 4302      5.0                        Perfect with GoPro Black 3+
# 4072      5.0               Used for my Samsung Galaxy Tab 2 7.0
# 1072      5.0               Works wonders for the Galaxy Note 2!
# 2583      5.0                  Works Great with a GoPro 3 Black!
# 121       5.0                     ready for use on the Galaxy S3
# 1142      5.0                          Great large capacity card
# 1753      5.0                    Use Nothing Other Than the Best
#
#       unixReviewTime  reviewTime  day_diff  helpful_yes  total_vote  \
# 2031      1367366400  2013-01-05       702         1952        2020
# 3449      1348617600  2012-09-26       803         1428        1505
# 4212      1375660800  2013-05-08       579         1568        1694
# 317       1346544000  2012-02-09      1033          422         495
# 4672      1394150400  2014-07-03       158           45          49
# 1835      1393545600  2014-02-28       283           60          68
# 3981      1350864000  2012-10-22       777          112         139
# 3807      1361923200  2013-02-27       649           22          25
# 4306      1339200000  2012-09-06       823           51          65
# 4596      1348272000  2012-09-22       807           82         109
# 315       1344816000  2012-08-13       847           38          48
# 1465      1397433600  2014-04-14       238            7           7
# 1609      1395792000  2014-03-26       257            7           7
# 4302      1395360000  2014-03-21       262           14          16
# 4072      1347321600  2012-11-09       759            6           6
# 1072      1349395200  2012-05-10       942            5           5
# 2583      1370649600  2013-08-06       489            5           5
# 121       1346803200  2012-05-09       943            5           5
# 1142      1396396800  2014-02-04       307            5           5
# 1753      1350864000  2012-10-22       777            5           5
#
#       helpful_no  score_pos_neg_diff  score_average_rating  wilson_lower_bound
# 2031          68                1884              0.966337            0.957544
# 3449          77                1351              0.948837            0.936519
# 4212         126                1442              0.925620            0.912139
# 317           73                 349              0.852525            0.818577
# 4672           4                  41              0.918367            0.808109
# 1835           8                  52              0.882353            0.784651
# 3981          27                  85              0.805755            0.732136
# 3807           3                  19              0.880000            0.700442
# 4306          14                  37              0.784615            0.670334
# 4596          27                  55              0.752294            0.663595
# 315           10                  28              0.791667            0.657411
# 1465           0                   7              1.000000            0.645670
# 1609           0                   7              1.000000            0.645670
# 4302           2                  12              0.875000            0.639772
# 4072           0                   6              1.000000            0.609666
# 1072           0                   5              1.000000            0.565518
# 2583           0                   5              1.000000            0.565518
# 121            0                   5              1.000000            0.565518
# 1142           0                   5              1.000000            0.565518
# 1753           0                   5              1.000000            0.565518

# %% [markdown]
# ### Step3:Result

# %% [markdown]
# Sort first 20 comments to the wilson_lower_bound then make a comment.

# %%
df.sort_values("wilson_lower_bound",ascending=False).head(20)
# Out:
#           reviewerID        asin                          reviewerName  \
# 2031  A12B7ZMXFI6IXY  B007WTAJTO                  Hyoun Kim "Faluzure"
# 3449   AOEAD7DPLZE53  B007WTAJTO                     NLee the Engineer
# 4212   AVBMZZAFEKO58  B007WTAJTO                           SkincareCEO
# 317   A1ZQAQFYSXL5MQ  B007WTAJTO               Amazon Customer "Kelly"
# 4672  A2DKQQIZ793AV5  B007WTAJTO                               Twister
# 1835  A1J6VSUM80UAF8  B007WTAJTO                           goconfigure
# 3981  A1K91XXQ6ZEBQR  B007WTAJTO            R. Sutton, Jr. "RWSynergy"
# 3807   AFGRMORWY2QNX  B007WTAJTO                            R. Heisler
# 4306   AOHXKM5URSKAB  B007WTAJTO                         Stellar Eller
# 4596  A1WTQUOQ4WG9AI  B007WTAJTO           Tom Henriksen "Doggy Diner"
# 315   A2J26NNQX6WKAU  B007WTAJTO            Amazon Customer "johncrea"
# 1465   A6I8KXYK24RTB  B007WTAJTO                              D. Stein
# 1609  A2TPXOZSU1DACQ  B007WTAJTO                                Eskimo
# 4302  A2EL2GWJ9T0DWY  B007WTAJTO                             Stayeraug
# 4072  A22GOZTFA02O2F  B007WTAJTO                           sb21 "sb21"
# 1072  A2O96COBMVY9C4  B007WTAJTO                        Crysis Complex
# 2583  A3MEPYZVTAV90W  B007WTAJTO                               J. Wong
# 121   A2Z4VVF1NTJWPB  B007WTAJTO                                A. Lee
# 1142  A1PLHPPAJ5MUXG  B007WTAJTO  Daniel Pham(Danpham_X @ yahoo.  com)
# 1753   ALPLKR59QMBUX  B007WTAJTO                             G. Becker
#
#            helpful                                         reviewText  \
# 2031  [1952, 2020]  [[ UPDATE - 6/19/2014 ]]So my lovely wife boug...
# 3449  [1428, 1505]  I have tested dozens of SDHC and micro-SDHC ca...
# 4212  [1568, 1694]  NOTE:  please read the last update (scroll to ...
# 317     [422, 495]  If your card gets hot enough to be painful, it...
# 4672      [45, 49]  Sandisk announcement of the first 128GB micro ...
# 1835      [60, 68]  Bought from BestBuy online the day it was anno...
# 3981    [112, 139]  The last few days I have been diligently shopp...
# 3807      [22, 25]  I bought this card to replace a lost 16 gig in...
# 4306      [51, 65]  While I got this card as a "deal of the day" o...
# 4596     [82, 109]  Hi:I ordered two card and they arrived the nex...
# 315       [38, 48]  Bought this card to use with my Samsung Galaxy...
# 1465        [7, 7]  I for one have not bought into Google's, or an...
# 1609        [7, 7]  I have always been a sandisk guy.  This cards ...
# 4302      [14, 16]  So I got this SD specifically for my GoPro Bla...
# 4072        [6, 6]  I used this for my Samsung Galaxy Tab 2 7.0 . ...
# 1072        [5, 5]  What more can I say? The 64GB micro SD works f...
# 2583        [5, 5]  I bought this Class 10 SD card for my GoPro 3 ...
# 121         [5, 5]  Update: providing an update with regard to San...
# 1142        [5, 5]  As soon as I saw that this card was announced ...
# 1753        [5, 5]  Puchased this card right after I received my S...
#
#       overall                                            summary  \
# 2031      5.0  UPDATED - Great w/ Galaxy S4 & Galaxy Tab 4 10...
# 3449      5.0  Top of the class among all (budget-priced) mic...
# 4212      1.0  1 Star reviews - Micro SDXC card unmounts itse...
# 317       1.0                                Warning, read this!
# 4672      5.0  Super high capacity!!!  Excellent price (on Am...
# 1835      5.0                                           I own it
# 3981      5.0  Resolving confusion between "Mobile Ultra" and...
# 3807      3.0   Good buy for the money but wait, I had an issue!
# 4306      5.0                                      Awesome Card!
# 4596      1.0     Designed incompatibility/Don't support SanDisk
# 315       5.0  Samsung Galaxy Tab2 works with this card if re...
# 1465      4.0                                           Finally.
# 1609      5.0                  Bet you wish you had one of these
# 4302      5.0                        Perfect with GoPro Black 3+
# 4072      5.0               Used for my Samsung Galaxy Tab 2 7.0
# 1072      5.0               Works wonders for the Galaxy Note 2!
# 2583      5.0                  Works Great with a GoPro 3 Black!
# 121       5.0                     ready for use on the Galaxy S3
# 1142      5.0                          Great large capacity card
# 1753      5.0                    Use Nothing Other Than the Best
#
#       unixReviewTime  reviewTime  day_diff  helpful_yes  total_vote  \
# 2031      1367366400  2013-01-05       702         1952        2020
# 3449      1348617600  2012-09-26       803         1428        1505
# 4212      1375660800  2013-05-08       579         1568        1694
# 317       1346544000  2012-02-09      1033          422         495
# 4672      1394150400  2014-07-03       158           45          49
# 1835      1393545600  2014-02-28       283           60          68
# 3981      1350864000  2012-10-22       777          112         139
# 3807      1361923200  2013-02-27       649           22          25
# 4306      1339200000  2012-09-06       823           51          65
# 4596      1348272000  2012-09-22       807           82         109
# 315       1344816000  2012-08-13       847           38          48
# 1465      1397433600  2014-04-14       238            7           7
# 1609      1395792000  2014-03-26       257            7           7
# 4302      1395360000  2014-03-21       262           14          16
# 4072      1347321600  2012-11-09       759            6           6
# 1072      1349395200  2012-05-10       942            5           5
# 2583      1370649600  2013-08-06       489            5           5
# 121       1346803200  2012-05-09       943            5           5
# 1142      1396396800  2014-02-04       307            5           5
# 1753      1350864000  2012-10-22       777            5           5
#
#       helpful_no  score_pos_neg_diff  score_average_rating  wilson_lower_bound
# 2031          68                1884              0.966337            0.957544
# 3449          77                1351              0.948837            0.936519
# 4212         126                1442              0.925620            0.912139
# 317           73                 349              0.852525            0.818577
# 4672           4                  41              0.918367            0.808109
# 1835           8                  52              0.882353            0.784651
# 3981          27                  85              0.805755            0.732136
# 3807           3                  19              0.880000            0.700442
# 4306          14                  37              0.784615            0.670334
# 4596          27                  55              0.752294            0.663595
# 315           10                  28              0.791667            0.657411
# 1465           0                   7              1.000000            0.645670
# 1609           0                   7              1.000000            0.645670
# 4302           2                  12              0.875000            0.639772
# 4072           0                   6              1.000000            0.609666
# 1072           0                   5              1.000000            0.565518
# 2583           0                   5              1.000000            0.565518
# 121            0                   5              1.000000            0.565518
# 1142           0                   5              1.000000            0.565518
# 1753           0                   5              1.000000            0.565518

# %% [markdown]
# We see the first 5 products has the most comments then wilson lower bound make them in the first row then we see some of the products has less comments then the other products but still they are before in the sorting becuase their helpful comment ratio is better than other products.
